
        super().__init__()
        self.conv = nn.Conv2d(in_channels, 512, kernel_size=3, stride=1, padding=1)
        self.cls_logits = nn.Conv2d(512, num_anchors, kernel_size=1)
        self.bbox_pred = nn.Conv2d(512, num_anchors * 4, kernel_size=1)

    def forward(self, x):
        x = F.relu(self.conv(x))
        logits = self.cls_logits(x)
        bbox_pred = self.bbox_pred(x)
        return logits, bbox_pred

# %%
class BoxHead(nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        self.fc1 = nn.Linear(in_channels, 1024)  # ✅ Input should be 12544
        self.fc2 = nn.Linear(1024, 1024)
        self.cls_score = nn.Linear(1024, num_classes)  # ✅ Class logits
        self.bbox_pred = nn.Linear(1024, num_classes * 4)  # ✅ Bounding box regression

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        cls_logits = self.cls_score(x)  # ✅ Class Scores
        bbox_preds = self.bbox_pred(x)  # ✅ Box Predictions
        return cls_logits, bbox_preds

# %%
# Custom Mask Head (Fully Convolutional Layers)
class MaskHead(nn.Module):
    def __init__(self, in_channels, hidden_dim=256, num_classes=91):
        super().__init__()
        self.conv1 = nn.Conv2d(in_channels, hidden_dim, kernel_size=3, padding=1)
        self.conv2 = nn.Conv2d(hidden_dim, hidden_dim, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(hidden_dim, hidden_dim, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(hidden_dim, hidden_dim, kernel_size=3, padding=1)
        self.conv5 = nn.Conv2d(hidden_dim, num_classes, kernel_size=1)

    def forward(self, x):
        x = F.relu(self.conv1(x))
        x = F.relu(self.conv2(x))
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = self.conv5(x)
        return x

# %%
import torchvision.models.detection.backbone_utils as backbone_utils
from torchvision.models.detection import FasterRCNN
from torchvision.models.detection.backbone_utils import resnet_fpn_backbone

def get_resnet_backbone():
    backbone = resnet_fpn_backbone("resnet50", weights="DEFAULT")  # ✅ Use ResNet50 with FPN
    return backbone

# %%
class MaskRCNN(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.num_classes = num_classes
        self.backbone = get_resnet_backbone()  # ✅ Use Pretrained ResNet
        self.rpn = RPN(2048, num_anchors=9)
        self.roi_pool = MultiScaleRoIAlign(featmap_names=["0", "1", "2", "3"], output_size=7, sampling_ratio=2)
        self.box_head = BoxHead(7 * 7 * 256, num_classes)  # ✅ Bounding Box Head
        self.mask_head = MaskHead(256, num_classes=num_classes)  # ✅ Mask Head

    def forward(self, images, proposals=None):
        features = self.backbone(images)  # ✅ Extract features

        # ✅ Fix `feature_dict` to correctly handle different backbone outputs
        if isinstance(features, dict):
            feature_dict = features  # ✅ Already a dictionary (FPN case)
        elif isinstance(features, list):
            feature_dict = {str(i): feat for i, feat in enumerate(features)}  # ✅ Convert list to dict
        else:
            feature_dict = {"0": features}  # ✅ Single tensor case (No FPN)

        # ✅ Generate proposals if not provided
        if proposals is None:
            rpn_logits, rpn_bbox = self.rpn(features)
            proposals = rpn_bbox

        # ✅ Fix `image_shapes` format
        image_shapes = [(images.shape[-2], images.shape[-1])] * images.shape[0]

        # ✅ Convert `proposals` into List[Tensor]
        proposals_per_image = []
        batch_size = images.shape[0]

        for i in range(batch_size):
            mask = proposals[:, 0] == i  # ✅ Select proposals for image `i`
            if mask.sum() == 0:  # ✅ Handle empty proposals
                proposals_per_image.append(torch.empty((0, 4), dtype=proposals.dtype, device=proposals.device))
            else:
                proposals_per_image.append(proposals[mask][:, 1:])  # ✅ Remove batch index column

        # ✅ Apply RoI Align
        pooled_regions = self.roi_pool(feature_dict, proposals_per_image, image_shapes)

        # ✅ Ensure `pooled_regions` is not empty
        if pooled_regions.numel() == 0:
            raise ValueError("❌ RoIAlign produced empty regions, check proposals input.")

        # ✅ Ensure correct shape before passing to BoxHead
        if pooled_regions.dim() != 4:
            raise ValueError(f"❌ Expected 4D tensor (N, C, 7, 7), got {pooled_regions.shape}")

        # ✅ Get feature map size
        C, H, W = pooled_regions.shape[1], pooled_regions.shape[2], pooled_regions.shape[3]
        expected_size = C * H * W  # Should be 256 * 7 * 7 = 12544

        # ✅ Ensure correct reshaping
        if expected_size != 12544:
            raise ValueError(f"❌ Feature map has incorrect channels: {C}. Expected 256.")

        flattened_pooled = pooled_regions.view(pooled_regions.size(0), expected_size)

        # ✅ Debugging Print (Optional)
        if batch_idx == 0:  # ✅ Print only for the first batch of each epoch
           print(f"✅ Reshaped pooled_regions: Expected {expected_size}, Got {flattened_pooled.shape[1]}")


        # ✅ Compute Class & Box Predictions
        class_logits, bbox_deltas = self.box_head(flattened_pooled)

        # ✅ Compute Mask Predictions
        masks = self.mask_head(pooled_regions)

        return class_logits, bbox_deltas, masks

# %%
import os

train_images_path = "train2017"
annotations_path = "annotations/instances_train2017.json"

# Check if the image directory exists
print("Train Images Exist:", os.path.exists(train_images_path))

# Check if the annotations file exists
print("Annotations Exist:", os.path.exists(annotations_path))
# Out:
# Train Images Exist: True
# Annotations Exist: True

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.models as models
from torchvision.ops import RoIAlign
from torch.utils.data import DataLoader, Dataset
import numpy as np
import cv2
import os
import json
import time
from PIL import Image
from pycocotools.coco import COCO

# ✅ Set Device (GPU or CPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using Device: {device}")

# ✅ COCO Dataset Class (Optimized)
class COCODataset(Dataset):
    def __init__(self, image_dir, annotation_file, transform=None):
        self.image_dir = image_dir
        self.coco = COCO(annotation_file)
        self.img_ids = list(self.coco.imgs.keys())[:50000]  # ✅ Use only 20,000 images
        self.transform = transform
        self.img_size = (128, 128)  # ✅ Resize to 128x128 for faster training

    def __len__(self):
        return len(self.img_ids)

    def __getitem__(self, idx):
        img_id = self.img_ids[idx]
        ann_ids = self.coco.getAnnIds(imgIds=img_id)
        anns = self.coco.loadAnns(ann_ids)

        img_info = self.coco.loadImgs(img_id)[0]
        img_path = os.path.join(self.image_dir, img_info['file_name'])
        image = Image.open(img_path).convert("RGB")

        # ✅ Resize image
        image = image.resize(self.img_size, Image.BILINEAR)

        # Get bounding boxes & masks
        boxes, masks, labels = [], [], []

        for ann in anns:
            x, y, w, h = ann['bbox']
            x1, y1, x2, y2 = x, y, x + w, y + h
            boxes.append([x1, y1, x2, y2])

            mask = self.coco.annToMask(ann)
            mask = cv2.resize(mask, self.img_size)  # Resize mask
            masks.append(mask)

            labels.append(ann['category_id'])

        # ✅ Handle Empty Annotations
        if len(boxes) == 0 or len(labels) == 0:
            return self.__getitem__((idx + 1) % len(self.img_ids))  # Skip empty images

        # ✅ Convert to tensors
        boxes = torch.tensor(boxes, dtype=torch.float32).reshape(-1, 4)  # Shape (N, 4)
        masks = torch.tensor(np.array(masks), dtype=torch.uint8).unsqueeze(1)  # Shape (N, 1, H, W)
        labels = torch.tensor(labels, dtype=torch.int64).flatten()  # Shape (N,)

        if self.transform:
            image = self.transform(image)

        return image, boxes, masks, labels

# ✅ Transforms
transform = transforms.Compose([
    transforms.Resize((128, 128)),  # Resize images
    transforms.RandomHorizontalFlip(p=0.5),  # ✅ Flip images randomly
    transforms.RandomRotation(degrees=10),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2),  # ✅ Improve feature learning
    transforms.GaussianBlur(kernel_size=(3, 3), sigma=(0.1, 2.0)),  # ✅ Reduce noise
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])  # ✅ Normalize using ImageNet stats
])

# ✅ Collate Function to Handle Variable-Sized Batches
def collate_fn(batch):
    images, boxes, masks, labels = zip(*batch)
    images = torch.stack(images, dim=0)  # Stack images into a single tensor
    return images, boxes, masks, labels  # Keep boxes/masks/lables as lists

# ✅ Create Dataset & DataLoader (Optimized)
train_dataset = COCODataset("train2017", "annotations/instances_train2017.json", transform)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)

# ✅ Check Dataset
print(f"Total images in dataset: {len(train_dataset)}")
for images, boxes, masks, labels in train_loader:
    print(f"Batch size: {len(images)}")
    print(f"Image shape: {images[0].shape}")
    print(f"Boxes shape: {boxes[0].shape}")
    print(f"Masks shape: {masks[0].shape}")
    print(f"Labels: {labels[0]}")
    break  # ✅ Stop after first batch check
# Out:
# Using Device: cuda
# loading annotations into memory...
# Done (t=15.30s)
# creating index...
# index created!
# Total images in dataset: 50000
# Batch size: 16
# Image shape: torch.Size([3, 128, 128])
# Boxes shape: torch.Size([7, 4])
# Masks shape: torch.Size([7, 1, 128, 128])
# Labels: tensor([77, 77, 77, 77, 62,  1,  1])

# %%
import torch
print(f"CUDA Available: {torch.cuda.is_available()}")
print(f"Device: {torch.device('cuda' if torch.cuda.is_available() else 'cpu')}")
# Out:
# CUDA Available: True
# Device: cuda

# %%
import time

start = time.time()
data = next(iter(train_loader))  # Load one batch
end = time.time()

print(f"⏳ Time to load one batch: {end - start:.4f} seconds")
# Out:
# ⏳ Time to load one batch: 0.8592 seconds

# %%
import time
import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
from torch.cuda.amp import autocast, GradScaler
from torchvision import transforms

# ✅ Data Augmentation
train_transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ColorJitter(brightness=0.3, contrast=0.3, saturation=0.3, hue=0.05),
    transforms.RandomPerspective(distortion_scale=0.2, p=0.5),  # Improves robustness
    transforms.RandomAffine(degrees=15, scale=(0.8, 1.2), shear=10),
    transforms.RandomErasing(p=0.3, scale=(0.02, 0.2)),  # Simulates occlusion
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# ✅ Load Model & Optimizer
device = "cuda" if torch.cuda.is_available() else "cpu"
model = MaskRCNN(num_classes=91).to(device)
optimizer = optim.AdamW(model.parameters(), lr=0.0005, weight_decay=0.0001)  # AdamW is a good optimizer
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=10)

# ✅ Loss Functions
class FocalLoss(nn.Module):
    def __init__(self, alpha=0.25, gamma=2.0):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.ce_loss = nn.CrossEntropyLoss(reduction="none")

    def forward(self, logits, targets):
        ce_loss = self.ce_loss(logits, targets)
        pt = torch.exp(-ce_loss)  # Probability of the correct class
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

loss_fn_cls = FocalLoss(alpha=0.25, gamma=2.0)

loss_fn_bbox = nn.SmoothL1Loss()
loss_fn_mask = nn.BCEWithLogitsLoss()

scaler = GradScaler()

# ✅ Training Loop
epochs = 85
accumulate_steps = 8

for epoch in range(epochs):
    model.train()
    start_time = time.time()
    total_loss, correct_preds, total_preds = 0, 0, 0

    for batch_idx, (images, boxes, masks, labels) in enumerate(train_loader):
        images = torch.stack([img.to(device) for img in images])
        boxes = [b.to(device) for b in boxes]
        masks = [m.to(device) for m in masks]
        labels = [l.to(device) for l in labels]

        # ✅ Skip Empty Labels to Prevent Errors
        if len(labels) == 0 or len(boxes) == 0:
            print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
            continue

        # ✅ Normalize & Clamp Bounding Boxes
        for i in range(len(boxes)):
            image_w, image_h = images.shape[3], images.shape[2]
            boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
            boxes[i] = torch.clamp(boxes[i], min=0, max=1)

        num_proposals = min(32, max(len(b) for b in boxes))
        proposals, proposal_labels, proposal_boxes = [], [], []

        for i, (b, l) in enumerate(zip(boxes, labels)):
            if len(b) == 0:
                continue
            b_idx = torch.full((b.shape[0], 1), i, dtype=torch.float32, device=device)
            formatted_boxes = torch.cat((b_idx, b[:, :4]), dim=1)
            proposals.append(formatted_boxes[:num_proposals])
            proposal_labels.append(l[:num_proposals])
            proposal_boxes.append(b[:num_proposals])

        if len(proposals) > 0:
            proposals = torch.cat(proposals, dim=0).to(device)
            proposal_labels = torch.cat(proposal_labels, dim=0).to(device)
            proposal_boxes = torch.cat(proposal_boxes, dim=0).to(device)
        else:
            proposals = torch.zeros((1, 5), dtype=torch.float32, device=device)
            proposal_labels = torch.zeros((1,), dtype=torch.int64, device=device)
            proposal_boxes = torch.zeros((1, 4), dtype=torch.float32, device=device)

        # ✅ Forward Pass with Mixed Precision
        with autocast():
            class_logits, bbox_deltas, mask_logits = model(images, proposals)

        # ✅ Compute Losses
        loss_cls = loss_fn_cls(class_logits, proposal_labels)
        selected_bbox_deltas = bbox_deltas.view(-1, 91, 4)
        predicted_classes = torch.argmax(class_logits, dim=1)
        selected_bbox_deltas = selected_bbox_deltas[torch.arange(selected_bbox_deltas.size(0)), predicted_classes]
        loss_bbox = loss_fn_bbox(selected_bbox_deltas, proposal_boxes)

        resized_masks = F.interpolate(masks[0].float(), size=mask_logits.shape[-2:], mode="bilinear", align_corners=False)

        # ✅ Ensure masks match mask_logits channels
        if resized_masks.shape[1] == 1 and mask_logits.shape[1] > 1:
            resized_masks = resized_masks.repeat(1, mask_logits.shape[1], 1, 1)
        elif resized_masks.shape[1] > 1 and mask_logits.shape[1] == 1:
            resized_masks = resized_masks[:, :1, :, :]

        # ✅ Ensure batch sizes match
        if resized_masks.shape[0] < mask_logits.shape[0]:
            pad_size = mask_logits.shape[0] - resized_masks.shape[0]
            padding = torch.zeros((pad_size, mask_logits.shape[1], *mask_logits.shape[-2:]), dtype=resized_masks.dtype, device=resized_masks.device)
            resized_masks = torch.cat([resized_masks, padding], dim=0)
        elif resized_masks.shape[0] > mask_logits.shape[0]:
            resized_masks = resized_masks[:mask_logits.shape[0]]

        loss_mask = loss_fn_mask(mask_logits, resized_masks)

        # ✅ Total Loss (Normalized)
        loss = (loss_cls + loss_bbox + loss_mask) / len(images)

        # ✅ Convert NaN Losses to Zero & Skip Unstable Batches
        loss = torch.nan_to_num(loss, nan=0.0, posinf=0.0, neginf=0.0)
        if loss == 0 or torch.isnan(loss) or torch.isinf(loss):
            print(f"⚠️ Skipping batch {batch_idx} due to unstable loss")
            optimizer.zero_grad()
            continue

        # ✅ Gradient Accumulation with Clipping
        scaler.scale(loss).backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=1.0)  # Clip gradients
        if (batch_idx + 1) % accumulate_steps == 0:
            scaler.step(optimizer)
            scaler.update()
            optimizer.zero_grad()

        total_loss += loss.item()

        preds = torch.argmax(class_logits, dim=1)
        labels_flat = torch.cat(proposal_labels, dim=0) if isinstance(proposal_labels, list) else proposal_labels

        # ✅ Track Accuracy
        min_size = min(labels_flat.shape[0], preds.shape[0])
        correct_preds += (preds[:min_size] == labels_flat[:min_size]).sum().item()
        total_preds += min_size

        if batch_idx % 100 == 0:
            print(f"🟢 Epoch {epoch+1}, Batch {batch_idx}/{len(train_loader)}: Loss {loss.item():.4f}")

    # ✅ Compute Training Accuracy
    scheduler.step()
    train_accuracy = correct_preds / total_preds if total_preds > 0 else 0.0
    epoch_time = time.time() - start_time

    print(f"✅ Epoch {epoch+1} Done: Loss {total_loss:.4f}, Train Acc: {train_accuracy:.4f}, Time: {epoch_time:.2f}s")

    # ✅ Print Learning Rate
    current_lr = optimizer.param_groups[0]['lr']
    print(f"📉 Learning Rate after Epoch {epoch+1}: {current_lr:.6f}")
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:135: UserWarning: Using 'backbone_name' as positional parameter(s) is deprecated since 0.13 and may be removed in the future. Please use keyword parameter(s) instead.
#   warnings.warn(
# <ipython-input-56-2797a87fe686>:50: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-56-2797a87fe686>:100: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 1, Batch 0/3125: Loss 0.1416
# 🟢 Epoch 1, Batch 100/3125: Loss 0.1059
# 🟢 Epoch 1, Batch 200/3125: Loss 0.0691
# 🟢 Epoch 1, Batch 300/3125: Loss 0.0522
# 🟢 Epoch 1, Batch 400/3125: Loss 0.0574
# 🟢 Epoch 1, Batch 500/3125: Loss 0.0589
# 🟢 Epoch 1, Batch 600/3125: Loss 0.0641
# 🟢 Epoch 1, Batch 700/3125: Loss 0.0542
# 🟢 Epoch 1, Batch 800/3125: Loss 0.0555
# 🟢 Epoch 1, Batch 900/3125: Loss 0.0500
# 🟢 Epoch 1, Batch 1000/3125: Loss 0.0606
# 🟢 Epoch 1, Batch 1100/3125: Loss 0.0464
# 🟢 Epoch 1, Batch 1200/3125: Loss 0.0497
# 🟢 Epoch 1, Batch 1300/3125: Loss 0.0481
# 🟢 Epoch 1, Batch 1400/3125: Loss 0.0527
# 🟢 Epoch 1, Batch 1500/3125: Loss 0.0531
# 🟢 Epoch 1, Batch 1600/3125: Loss 0.0577
# 🟢 Epoch 1, Batch 1700/3125: Loss 0.0455
# 🟢 Epoch 1, Batch 1800/3125: Loss 0.0562
# 🟢 Epoch 1, Batch 1900/3125: Loss 0.0537
# 🟢 Epoch 1, Batch 2000/3125: Loss 0.0545
# 🟢 Epoch 1, Batch 2100/3125: Loss 0.0538
# 🟢 Epoch 1, Batch 2200/3125: Loss 0.0470
# 🟢 Epoch 1, Batch 2300/3125: Loss 0.0465
# 🟢 Epoch 1, Batch 2400/3125: Loss 0.0525
# 🟢 Epoch 1, Batch 2500/3125: Loss 0.0565
# 🟢 Epoch 1, Batch 2600/3125: Loss 0.0682
# 🟢 Epoch 1, Batch 2700/3125: Loss 0.0514
# 🟢 Epoch 1, Batch 2800/3125: Loss 0.0427
# 🟢 Epoch 1, Batch 2900/3125: Loss 0.0423
# 🟢 Epoch 1, Batch 3000/3125: Loss 0.0469
# 🟢 Epoch 1, Batch 3100/3125: Loss 0.0454
# ✅ Epoch 1 Done: Loss 179.3547, Train Acc: 0.2987, Time: 226.22s
# 📉 Learning Rate after Epoch 1: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 2, Batch 0/3125: Loss 0.0456
# 🟢 Epoch 2, Batch 100/3125: Loss 0.0585
# 🟢 Epoch 2, Batch 200/3125: Loss 0.0502
# 🟢 Epoch 2, Batch 300/3125: Loss 0.0463
# 🟢 Epoch 2, Batch 400/3125: Loss 0.0487
# 🟢 Epoch 2, Batch 500/3125: Loss 0.0515
# 🟢 Epoch 2, Batch 600/3125: Loss 0.0462
# 🟢 Epoch 2, Batch 700/3125: Loss 0.0497
# 🟢 Epoch 2, Batch 800/3125: Loss 0.0519
# 🟢 Epoch 2, Batch 900/3125: Loss 0.0451
# 🟢 Epoch 2, Batch 1000/3125: Loss 0.0576
# 🟢 Epoch 2, Batch 1100/3125: Loss 0.0531
# 🟢 Epoch 2, Batch 1200/3125: Loss 0.0550
# 🟢 Epoch 2, Batch 1300/3125: Loss 0.0529
# 🟢 Epoch 2, Batch 1400/3125: Loss 0.0405
# 🟢 Epoch 2, Batch 1500/3125: Loss 0.0514
# 🟢 Epoch 2, Batch 1600/3125: Loss 0.0547
# 🟢 Epoch 2, Batch 1700/3125: Loss 0.0423
# 🟢 Epoch 2, Batch 1800/3125: Loss 0.0489
# 🟢 Epoch 2, Batch 1900/3125: Loss 0.0612
# 🟢 Epoch 2, Batch 2000/3125: Loss 0.0481
# 🟢 Epoch 2, Batch 2100/3125: Loss 0.0454
# 🟢 Epoch 2, Batch 2200/3125: Loss 0.0538
# 🟢 Epoch 2, Batch 2300/3125: Loss 0.0448
# 🟢 Epoch 2, Batch 2400/3125: Loss 0.0395
# 🟢 Epoch 2, Batch 2500/3125: Loss 0.0458
# 🟢 Epoch 2, Batch 2600/3125: Loss 0.0590
# 🟢 Epoch 2, Batch 2700/3125: Loss 0.0397
# 🟢 Epoch 2, Batch 2800/3125: Loss 0.0516
# 🟢 Epoch 2, Batch 2900/3125: Loss 0.0522
# 🟢 Epoch 2, Batch 3000/3125: Loss 0.0443
# 🟢 Epoch 2, Batch 3100/3125: Loss 0.0548
# ✅ Epoch 2 Done: Loss 154.0765, Train Acc: 0.3019, Time: 224.39s
# 📉 Learning Rate after Epoch 2: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 3, Batch 0/3125: Loss 0.0478
# 🟢 Epoch 3, Batch 100/3125: Loss 0.0552
# 🟢 Epoch 3, Batch 200/3125: Loss 0.0479
# 🟢 Epoch 3, Batch 300/3125: Loss 0.0481
# 🟢 Epoch 3, Batch 400/3125: Loss 0.0426
# 🟢 Epoch 3, Batch 500/3125: Loss 0.0524
# 🟢 Epoch 3, Batch 600/3125: Loss 0.0492
# 🟢 Epoch 3, Batch 700/3125: Loss 0.0458
# 🟢 Epoch 3, Batch 800/3125: Loss 0.0431
# 🟢 Epoch 3, Batch 900/3125: Loss 0.0470
# 🟢 Epoch 3, Batch 1000/3125: Loss 0.0412
# 🟢 Epoch 3, Batch 1100/3125: Loss 0.0526
# 🟢 Epoch 3, Batch 1200/3125: Loss 0.0432
# 🟢 Epoch 3, Batch 1300/3125: Loss 0.0410
# 🟢 Epoch 3, Batch 1400/3125: Loss 0.0460
# 🟢 Epoch 3, Batch 1500/3125: Loss 0.0485
# 🟢 Epoch 3, Batch 1600/3125: Loss 0.0472
# 🟢 Epoch 3, Batch 1700/3125: Loss 0.0379
# 🟢 Epoch 3, Batch 1800/3125: Loss 0.0459
# 🟢 Epoch 3, Batch 1900/3125: Loss 0.0366
# 🟢 Epoch 3, Batch 2000/3125: Loss 0.0379
# 🟢 Epoch 3, Batch 2100/3125: Loss 0.0609
# 🟢 Epoch 3, Batch 2200/3125: Loss 0.0490
# 🟢 Epoch 3, Batch 2300/3125: Loss 0.0425
# 🟢 Epoch 3, Batch 2400/3125: Loss 0.0427
# 🟢 Epoch 3, Batch 2500/3125: Loss 0.0376
# 🟢 Epoch 3, Batch 2600/3125: Loss 0.0364
# 🟢 Epoch 3, Batch 2700/3125: Loss 0.0544
# 🟢 Epoch 3, Batch 2800/3125: Loss 0.0386
# 🟢 Epoch 3, Batch 2900/3125: Loss 0.0453
# 🟢 Epoch 3, Batch 3000/3125: Loss 0.0495
# 🟢 Epoch 3, Batch 3100/3125: Loss 0.0545
# ✅ Epoch 3 Done: Loss 143.6849, Train Acc: 0.3063, Time: 223.94s
# 📉 Learning Rate after Epoch 3: 0.000397
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 4, Batch 0/3125: Loss 0.0355
# 🟢 Epoch 4, Batch 100/3125: Loss 0.0409
# 🟢 Epoch 4, Batch 200/3125: Loss 0.0430
# 🟢 Epoch 4, Batch 300/3125: Loss 0.0339
# 🟢 Epoch 4, Batch 400/3125: Loss 0.0468
# 🟢 Epoch 4, Batch 500/3125: Loss 0.0475
# 🟢 Epoch 4, Batch 600/3125: Loss 0.0366
# 🟢 Epoch 4, Batch 700/3125: Loss 0.0364
# 🟢 Epoch 4, Batch 800/3125: Loss 0.0443
# 🟢 Epoch 4, Batch 900/3125: Loss 0.0379
# 🟢 Epoch 4, Batch 1000/3125: Loss 0.0398
# 🟢 Epoch 4, Batch 1100/3125: Loss 0.0353
# 🟢 Epoch 4, Batch 1200/3125: Loss 0.0413
# 🟢 Epoch 4, Batch 1300/3125: Loss 0.0533
# 🟢 Epoch 4, Batch 1400/3125: Loss 0.0382
# 🟢 Epoch 4, Batch 1500/3125: Loss 0.0411
# 🟢 Epoch 4, Batch 1600/3125: Loss 0.0350
# 🟢 Epoch 4, Batch 1700/3125: Loss 0.0527
# 🟢 Epoch 4, Batch 1800/3125: Loss 0.0448
# 🟢 Epoch 4, Batch 1900/3125: Loss 0.0457
# 🟢 Epoch 4, Batch 2000/3125: Loss 0.0338
# 🟢 Epoch 4, Batch 2100/3125: Loss 0.0488
# 🟢 Epoch 4, Batch 2200/3125: Loss 0.0362
# 🟢 Epoch 4, Batch 2300/3125: Loss 0.0448
# 🟢 Epoch 4, Batch 2400/3125: Loss 0.0428
# 🟢 Epoch 4, Batch 2500/3125: Loss 0.0410
# 🟢 Epoch 4, Batch 2600/3125: Loss 0.0416
# 🟢 Epoch 4, Batch 2700/3125: Loss 0.0385
# 🟢 Epoch 4, Batch 2800/3125: Loss 0.0437
# 🟢 Epoch 4, Batch 2900/3125: Loss 0.0441
# 🟢 Epoch 4, Batch 3000/3125: Loss 0.0439
# 🟢 Epoch 4, Batch 3100/3125: Loss 0.0429
# ✅ Epoch 4 Done: Loss 135.4218, Train Acc: 0.3101, Time: 222.51s
# 📉 Learning Rate after Epoch 4: 0.000327
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 5, Batch 0/3125: Loss 0.0366
# 🟢 Epoch 5, Batch 100/3125: Loss 0.0425
# 🟢 Epoch 5, Batch 200/3125: Loss 0.0412
# 🟢 Epoch 5, Batch 300/3125: Loss 0.0388
# 🟢 Epoch 5, Batch 400/3125: Loss 0.0428
# 🟢 Epoch 5, Batch 500/3125: Loss 0.0351
# 🟢 Epoch 5, Batch 600/3125: Loss 0.0471
# 🟢 Epoch 5, Batch 700/3125: Loss 0.0396
# 🟢 Epoch 5, Batch 800/3125: Loss 0.0362
# 🟢 Epoch 5, Batch 900/3125: Loss 0.0445
# 🟢 Epoch 5, Batch 1000/3125: Loss 0.0390
# 🟢 Epoch 5, Batch 1100/3125: Loss 0.0452
# 🟢 Epoch 5, Batch 1200/3125: Loss 0.0451
# 🟢 Epoch 5, Batch 1300/3125: Loss 0.0514
# 🟢 Epoch 5, Batch 1400/3125: Loss 0.0420
# 🟢 Epoch 5, Batch 1500/3125: Loss 0.0434
# 🟢 Epoch 5, Batch 1600/3125: Loss 0.0407
# 🟢 Epoch 5, Batch 1700/3125: Loss 0.0471
# 🟢 Epoch 5, Batch 1800/3125: Loss 0.0412
# 🟢 Epoch 5, Batch 1900/3125: Loss 0.0419
# 🟢 Epoch 5, Batch 2000/3125: Loss 0.0505
# 🟢 Epoch 5, Batch 2100/3125: Loss 0.0414
# 🟢 Epoch 5, Batch 2200/3125: Loss 0.0317
# 🟢 Epoch 5, Batch 2300/3125: Loss 0.0437
# 🟢 Epoch 5, Batch 2400/3125: Loss 0.0337
# 🟢 Epoch 5, Batch 2500/3125: Loss 0.0248
# 🟢 Epoch 5, Batch 2600/3125: Loss 0.0328
# 🟢 Epoch 5, Batch 2700/3125: Loss 0.0565
# 🟢 Epoch 5, Batch 2800/3125: Loss 0.0427
# 🟢 Epoch 5, Batch 2900/3125: Loss 0.0536
# 🟢 Epoch 5, Batch 3000/3125: Loss 0.0436
# 🟢 Epoch 5, Batch 3100/3125: Loss 0.0380
# ✅ Epoch 5 Done: Loss 128.2217, Train Acc: 0.3147, Time: 223.59s
# 📉 Learning Rate after Epoch 5: 0.000250
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 6, Batch 0/3125: Loss 0.0420
# 🟢 Epoch 6, Batch 100/3125: Loss 0.0347
# 🟢 Epoch 6, Batch 200/3125: Loss 0.0421
# 🟢 Epoch 6, Batch 300/3125: Loss 0.0437
# 🟢 Epoch 6, Batch 400/3125: Loss 0.0335
# 🟢 Epoch 6, Batch 500/3125: Loss 0.0288
# 🟢 Epoch 6, Batch 600/3125: Loss 0.0445
# 🟢 Epoch 6, Batch 700/3125: Loss 0.0462
# 🟢 Epoch 6, Batch 800/3125: Loss 0.0440
# 🟢 Epoch 6, Batch 900/3125: Loss 0.0452
# 🟢 Epoch 6, Batch 1000/3125: Loss 0.0383
# 🟢 Epoch 6, Batch 1100/3125: Loss 0.0397
# 🟢 Epoch 6, Batch 1200/3125: Loss 0.0375
# 🟢 Epoch 6, Batch 1300/3125: Loss 0.0374
# 🟢 Epoch 6, Batch 1400/3125: Loss 0.0411
# 🟢 Epoch 6, Batch 1500/3125: Loss 0.0365
# 🟢 Epoch 6, Batch 1600/3125: Loss 0.0354
# 🟢 Epoch 6, Batch 1700/3125: Loss 0.0405
# 🟢 Epoch 6, Batch 1800/3125: Loss 0.0287
# 🟢 Epoch 6, Batch 1900/3125: Loss 0.0350
# 🟢 Epoch 6, Batch 2000/3125: Loss 0.0464
# 🟢 Epoch 6, Batch 2100/3125: Loss 0.0486
# 🟢 Epoch 6, Batch 2200/3125: Loss 0.0460
# 🟢 Epoch 6, Batch 2300/3125: Loss 0.0315
# 🟢 Epoch 6, Batch 2400/3125: Loss 0.0356
# 🟢 Epoch 6, Batch 2500/3125: Loss 0.0386
# 🟢 Epoch 6, Batch 2600/3125: Loss 0.0394
# 🟢 Epoch 6, Batch 2700/3125: Loss 0.0310
# 🟢 Epoch 6, Batch 2800/3125: Loss 0.0420
# 🟢 Epoch 6, Batch 2900/3125: Loss 0.0434
# 🟢 Epoch 6, Batch 3000/3125: Loss 0.0275
# 🟢 Epoch 6, Batch 3100/3125: Loss 0.0320
# ✅ Epoch 6 Done: Loss 119.4708, Train Acc: 0.3263, Time: 223.83s
# 📉 Learning Rate after Epoch 6: 0.000173
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 7, Batch 0/3125: Loss 0.0302
# 🟢 Epoch 7, Batch 100/3125: Loss 0.0297
# 🟢 Epoch 7, Batch 200/3125: Loss 0.0323
# 🟢 Epoch 7, Batch 300/3125: Loss 0.0402
# 🟢 Epoch 7, Batch 400/3125: Loss 0.0464
# 🟢 Epoch 7, Batch 500/3125: Loss 0.0393
# 🟢 Epoch 7, Batch 600/3125: Loss 0.0372
# 🟢 Epoch 7, Batch 700/3125: Loss 0.0367
# 🟢 Epoch 7, Batch 800/3125: Loss 0.0256
# 🟢 Epoch 7, Batch 900/3125: Loss 0.0349
# 🟢 Epoch 7, Batch 1000/3125: Loss 0.0311
# 🟢 Epoch 7, Batch 1100/3125: Loss 0.0333
# 🟢 Epoch 7, Batch 1200/3125: Loss 0.0371
# 🟢 Epoch 7, Batch 1300/3125: Loss 0.0362
# 🟢 Epoch 7, Batch 1400/3125: Loss 0.0368
# 🟢 Epoch 7, Batch 1500/3125: Loss 0.0420
# 🟢 Epoch 7, Batch 1600/3125: Loss 0.0439
# 🟢 Epoch 7, Batch 1700/3125: Loss 0.0466
# 🟢 Epoch 7, Batch 1800/3125: Loss 0.0417
# 🟢 Epoch 7, Batch 1900/3125: Loss 0.0391
# 🟢 Epoch 7, Batch 2000/3125: Loss 0.0475
# 🟢 Epoch 7, Batch 2100/3125: Loss 0.0328
# 🟢 Epoch 7, Batch 2200/3125: Loss 0.0337
# 🟢 Epoch 7, Batch 2300/3125: Loss 0.0328
# 🟢 Epoch 7, Batch 2400/3125: Loss 0.0394
# 🟢 Epoch 7, Batch 2500/3125: Loss 0.0368
# 🟢 Epoch 7, Batch 2600/3125: Loss 0.0399
# 🟢 Epoch 7, Batch 2700/3125: Loss 0.0302
# 🟢 Epoch 7, Batch 2800/3125: Loss 0.0336
# 🟢 Epoch 7, Batch 2900/3125: Loss 0.0327
# 🟢 Epoch 7, Batch 3000/3125: Loss 0.0311
# 🟢 Epoch 7, Batch 3100/3125: Loss 0.0437
# ✅ Epoch 7 Done: Loss 113.8529, Train Acc: 0.3353, Time: 224.40s
# 📉 Learning Rate after Epoch 7: 0.000103
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 8, Batch 0/3125: Loss 0.0387
# 🟢 Epoch 8, Batch 100/3125: Loss 0.0319
# 🟢 Epoch 8, Batch 200/3125: Loss 0.0418
# 🟢 Epoch 8, Batch 300/3125: Loss 0.0363
# 🟢 Epoch 8, Batch 400/3125: Loss 0.0426
# 🟢 Epoch 8, Batch 500/3125: Loss 0.0380
# 🟢 Epoch 8, Batch 600/3125: Loss 0.0364
# 🟢 Epoch 8, Batch 700/3125: Loss 0.0354
# 🟢 Epoch 8, Batch 800/3125: Loss 0.0406
# 🟢 Epoch 8, Batch 900/3125: Loss 0.0338
# 🟢 Epoch 8, Batch 1000/3125: Loss 0.0376
# 🟢 Epoch 8, Batch 1100/3125: Loss 0.0326
# 🟢 Epoch 8, Batch 1200/3125: Loss 0.0344
# 🟢 Epoch 8, Batch 1300/3125: Loss 0.0261
# 🟢 Epoch 8, Batch 1400/3125: Loss 0.0351
# 🟢 Epoch 8, Batch 1500/3125: Loss 0.0347
# 🟢 Epoch 8, Batch 1600/3125: Loss 0.0443
# 🟢 Epoch 8, Batch 1700/3125: Loss 0.0350
# 🟢 Epoch 8, Batch 1800/3125: Loss 0.0298
# 🟢 Epoch 8, Batch 1900/3125: Loss 0.0322
# 🟢 Epoch 8, Batch 2000/3125: Loss 0.0361
# 🟢 Epoch 8, Batch 2100/3125: Loss 0.0409
# 🟢 Epoch 8, Batch 2200/3125: Loss 0.0316
# 🟢 Epoch 8, Batch 2300/3125: Loss 0.0401
# 🟢 Epoch 8, Batch 2400/3125: Loss 0.0280
# 🟢 Epoch 8, Batch 2500/3125: Loss 0.0319
# 🟢 Epoch 8, Batch 2600/3125: Loss 0.0317
# 🟢 Epoch 8, Batch 2700/3125: Loss 0.0447
# 🟢 Epoch 8, Batch 2800/3125: Loss 0.0416
# 🟢 Epoch 8, Batch 2900/3125: Loss 0.0343
# 🟢 Epoch 8, Batch 3000/3125: Loss 0.0351
# 🟢 Epoch 8, Batch 3100/3125: Loss 0.0310
# ✅ Epoch 8 Done: Loss 110.6788, Train Acc: 0.3416, Time: 222.88s
# 📉 Learning Rate after Epoch 8: 0.000048
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 9, Batch 0/3125: Loss 0.0429
# 🟢 Epoch 9, Batch 100/3125: Loss 0.0372
# 🟢 Epoch 9, Batch 200/3125: Loss 0.0296
# 🟢 Epoch 9, Batch 300/3125: Loss 0.0295
# 🟢 Epoch 9, Batch 400/3125: Loss 0.0342
# 🟢 Epoch 9, Batch 500/3125: Loss 0.0356
# 🟢 Epoch 9, Batch 600/3125: Loss 0.0392
# 🟢 Epoch 9, Batch 700/3125: Loss 0.0371
# 🟢 Epoch 9, Batch 800/3125: Loss 0.0403
# 🟢 Epoch 9, Batch 900/3125: Loss 0.0331
# 🟢 Epoch 9, Batch 1000/3125: Loss 0.0399
# 🟢 Epoch 9, Batch 1100/3125: Loss 0.0374
# 🟢 Epoch 9, Batch 1200/3125: Loss 0.0287
# 🟢 Epoch 9, Batch 1300/3125: Loss 0.0374
# 🟢 Epoch 9, Batch 1400/3125: Loss 0.0350
# 🟢 Epoch 9, Batch 1500/3125: Loss 0.0427
# 🟢 Epoch 9, Batch 1600/3125: Loss 0.0304
# 🟢 Epoch 9, Batch 1700/3125: Loss 0.0368
# 🟢 Epoch 9, Batch 1800/3125: Loss 0.0375
# 🟢 Epoch 9, Batch 1900/3125: Loss 0.0380
# 🟢 Epoch 9, Batch 2000/3125: Loss 0.0319
# 🟢 Epoch 9, Batch 2100/3125: Loss 0.0374
# 🟢 Epoch 9, Batch 2200/3125: Loss 0.0356
# 🟢 Epoch 9, Batch 2300/3125: Loss 0.0347
# 🟢 Epoch 9, Batch 2400/3125: Loss 0.0355
# 🟢 Epoch 9, Batch 2500/3125: Loss 0.0282
# 🟢 Epoch 9, Batch 2600/3125: Loss 0.0401
# 🟢 Epoch 9, Batch 2700/3125: Loss 0.0342
# 🟢 Epoch 9, Batch 2800/3125: Loss 0.0305
# 🟢 Epoch 9, Batch 2900/3125: Loss 0.0259
# 🟢 Epoch 9, Batch 3000/3125: Loss 0.0273
# 🟢 Epoch 9, Batch 3100/3125: Loss 0.0363
# ✅ Epoch 9 Done: Loss 108.2336, Train Acc: 0.3503, Time: 223.65s
# 📉 Learning Rate after Epoch 9: 0.000012
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 10, Batch 0/3125: Loss 0.0365
# 🟢 Epoch 10, Batch 100/3125: Loss 0.0241
# 🟢 Epoch 10, Batch 200/3125: Loss 0.0302
# 🟢 Epoch 10, Batch 300/3125: Loss 0.0358
# 🟢 Epoch 10, Batch 400/3125: Loss 0.0412
# 🟢 Epoch 10, Batch 500/3125: Loss 0.0381
# 🟢 Epoch 10, Batch 600/3125: Loss 0.0330
# 🟢 Epoch 10, Batch 700/3125: Loss 0.0507
# 🟢 Epoch 10, Batch 800/3125: Loss 0.0287
# 🟢 Epoch 10, Batch 900/3125: Loss 0.0343
# 🟢 Epoch 10, Batch 1000/3125: Loss 0.0359
# 🟢 Epoch 10, Batch 1100/3125: Loss 0.0341
# 🟢 Epoch 10, Batch 1200/3125: Loss 0.0344
# 🟢 Epoch 10, Batch 1300/3125: Loss 0.0312
# 🟢 Epoch 10, Batch 1400/3125: Loss 0.0367
# 🟢 Epoch 10, Batch 1500/3125: Loss 0.0363
# 🟢 Epoch 10, Batch 1600/3125: Loss 0.0350
# 🟢 Epoch 10, Batch 1700/3125: Loss 0.0392
# 🟢 Epoch 10, Batch 1800/3125: Loss 0.0409
# 🟢 Epoch 10, Batch 1900/3125: Loss 0.0279
# 🟢 Epoch 10, Batch 2000/3125: Loss 0.0306
# 🟢 Epoch 10, Batch 2100/3125: Loss 0.0366
# 🟢 Epoch 10, Batch 2200/3125: Loss 0.0363
# 🟢 Epoch 10, Batch 2300/3125: Loss 0.0375
# 🟢 Epoch 10, Batch 2400/3125: Loss 0.0328
# 🟢 Epoch 10, Batch 2500/3125: Loss 0.0347
# 🟢 Epoch 10, Batch 2600/3125: Loss 0.0434
# 🟢 Epoch 10, Batch 2700/3125: Loss 0.0407
# 🟢 Epoch 10, Batch 2800/3125: Loss 0.0393
# 🟢 Epoch 10, Batch 2900/3125: Loss 0.0359
# 🟢 Epoch 10, Batch 3000/3125: Loss 0.0334
# 🟢 Epoch 10, Batch 3100/3125: Loss 0.0236
# ✅ Epoch 10 Done: Loss 106.6195, Train Acc: 0.3553, Time: 223.77s
# 📉 Learning Rate after Epoch 10: 0.000000
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 11, Batch 0/3125: Loss 0.0399
# 🟢 Epoch 11, Batch 100/3125: Loss 0.0375
# 🟢 Epoch 11, Batch 200/3125: Loss 0.0404
# 🟢 Epoch 11, Batch 300/3125: Loss 0.0277
# 🟢 Epoch 11, Batch 400/3125: Loss 0.0386
# 🟢 Epoch 11, Batch 500/3125: Loss 0.0302
# 🟢 Epoch 11, Batch 600/3125: Loss 0.0363
# 🟢 Epoch 11, Batch 700/3125: Loss 0.0260
# 🟢 Epoch 11, Batch 800/3125: Loss 0.0357
# 🟢 Epoch 11, Batch 900/3125: Loss 0.0307
# 🟢 Epoch 11, Batch 1000/3125: Loss 0.0381
# 🟢 Epoch 11, Batch 1100/3125: Loss 0.0488
# 🟢 Epoch 11, Batch 1200/3125: Loss 0.0309
# 🟢 Epoch 11, Batch 1300/3125: Loss 0.0287
# 🟢 Epoch 11, Batch 1400/3125: Loss 0.0284
# 🟢 Epoch 11, Batch 1500/3125: Loss 0.0288
# 🟢 Epoch 11, Batch 1600/3125: Loss 0.0382
# 🟢 Epoch 11, Batch 1700/3125: Loss 0.0311
# 🟢 Epoch 11, Batch 1800/3125: Loss 0.0374
# 🟢 Epoch 11, Batch 1900/3125: Loss 0.0369
# 🟢 Epoch 11, Batch 2000/3125: Loss 0.0340
# 🟢 Epoch 11, Batch 2100/3125: Loss 0.0307
# 🟢 Epoch 11, Batch 2200/3125: Loss 0.0417
# 🟢 Epoch 11, Batch 2300/3125: Loss 0.0327
# 🟢 Epoch 11, Batch 2400/3125: Loss 0.0279
# 🟢 Epoch 11, Batch 2500/3125: Loss 0.0285
# 🟢 Epoch 11, Batch 2600/3125: Loss 0.0276
# 🟢 Epoch 11, Batch 2700/3125: Loss 0.0301
# 🟢 Epoch 11, Batch 2800/3125: Loss 0.0454
# 🟢 Epoch 11, Batch 2900/3125: Loss 0.0395
# 🟢 Epoch 11, Batch 3000/3125: Loss 0.0353
# 🟢 Epoch 11, Batch 3100/3125: Loss 0.0312
# ✅ Epoch 11 Done: Loss 106.2601, Train Acc: 0.3559, Time: 223.21s
# 📉 Learning Rate after Epoch 11: 0.000012
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 12, Batch 0/3125: Loss 0.0354
# 🟢 Epoch 12, Batch 100/3125: Loss 0.0256
# 🟢 Epoch 12, Batch 200/3125: Loss 0.0388
# 🟢 Epoch 12, Batch 300/3125: Loss 0.0317
# 🟢 Epoch 12, Batch 400/3125: Loss 0.0254
# 🟢 Epoch 12, Batch 500/3125: Loss 0.0321
# 🟢 Epoch 12, Batch 600/3125: Loss 0.0371
# 🟢 Epoch 12, Batch 700/3125: Loss 0.0337
# 🟢 Epoch 12, Batch 800/3125: Loss 0.0391
# 🟢 Epoch 12, Batch 900/3125: Loss 0.0306
# 🟢 Epoch 12, Batch 1000/3125: Loss 0.0352
# 🟢 Epoch 12, Batch 1100/3125: Loss 0.0398
# 🟢 Epoch 12, Batch 1200/3125: Loss 0.0338
# 🟢 Epoch 12, Batch 1300/3125: Loss 0.0249
# 🟢 Epoch 12, Batch 1400/3125: Loss 0.0350
# 🟢 Epoch 12, Batch 1500/3125: Loss 0.0335
# 🟢 Epoch 12, Batch 1600/3125: Loss 0.0313
# 🟢 Epoch 12, Batch 1700/3125: Loss 0.0389
# 🟢 Epoch 12, Batch 1800/3125: Loss 0.0373
# 🟢 Epoch 12, Batch 1900/3125: Loss 0.0405
# 🟢 Epoch 12, Batch 2000/3125: Loss 0.0353
# 🟢 Epoch 12, Batch 2100/3125: Loss 0.0273
# 🟢 Epoch 12, Batch 2200/3125: Loss 0.0273
# 🟢 Epoch 12, Batch 2300/3125: Loss 0.0451
# 🟢 Epoch 12, Batch 2400/3125: Loss 0.0425
# 🟢 Epoch 12, Batch 2500/3125: Loss 0.0284
# 🟢 Epoch 12, Batch 2600/3125: Loss 0.0381
# 🟢 Epoch 12, Batch 2700/3125: Loss 0.0371
# 🟢 Epoch 12, Batch 2800/3125: Loss 0.0319
# 🟢 Epoch 12, Batch 2900/3125: Loss 0.0284
# 🟢 Epoch 12, Batch 3000/3125: Loss 0.0374
# 🟢 Epoch 12, Batch 3100/3125: Loss 0.0375
# ✅ Epoch 12 Done: Loss 106.0923, Train Acc: 0.3563, Time: 222.68s
# 📉 Learning Rate after Epoch 12: 0.000048
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 13, Batch 0/3125: Loss 0.0384
# 🟢 Epoch 13, Batch 100/3125: Loss 0.0270
# 🟢 Epoch 13, Batch 200/3125: Loss 0.0260
# 🟢 Epoch 13, Batch 300/3125: Loss 0.0379
# 🟢 Epoch 13, Batch 400/3125: Loss 0.0358
# 🟢 Epoch 13, Batch 500/3125: Loss 0.0309
# 🟢 Epoch 13, Batch 600/3125: Loss 0.0291
# 🟢 Epoch 13, Batch 700/3125: Loss 0.0246
# 🟢 Epoch 13, Batch 800/3125: Loss 0.0357
# 🟢 Epoch 13, Batch 900/3125: Loss 0.0338
# 🟢 Epoch 13, Batch 1000/3125: Loss 0.0291
# 🟢 Epoch 13, Batch 1100/3125: Loss 0.0287
# 🟢 Epoch 13, Batch 1200/3125: Loss 0.0364
# 🟢 Epoch 13, Batch 1300/3125: Loss 0.0331
# 🟢 Epoch 13, Batch 1400/3125: Loss 0.0405
# 🟢 Epoch 13, Batch 1500/3125: Loss 0.0378
# 🟢 Epoch 13, Batch 1600/3125: Loss 0.0360
# 🟢 Epoch 13, Batch 1700/3125: Loss 0.0348
# 🟢 Epoch 13, Batch 1800/3125: Loss 0.0271
# 🟢 Epoch 13, Batch 1900/3125: Loss 0.0404
# 🟢 Epoch 13, Batch 2000/3125: Loss 0.0317
# 🟢 Epoch 13, Batch 2100/3125: Loss 0.0378
# 🟢 Epoch 13, Batch 2200/3125: Loss 0.0399
# 🟢 Epoch 13, Batch 2300/3125: Loss 0.0350
# 🟢 Epoch 13, Batch 2400/3125: Loss 0.0269
# 🟢 Epoch 13, Batch 2500/3125: Loss 0.0336
# 🟢 Epoch 13, Batch 2600/3125: Loss 0.0355
# 🟢 Epoch 13, Batch 2700/3125: Loss 0.0301
# 🟢 Epoch 13, Batch 2800/3125: Loss 0.0342
# 🟢 Epoch 13, Batch 2900/3125: Loss 0.0297
# 🟢 Epoch 13, Batch 3000/3125: Loss 0.0282
# 🟢 Epoch 13, Batch 3100/3125: Loss 0.0380
# ✅ Epoch 13 Done: Loss 105.9650, Train Acc: 0.3562, Time: 223.42s
# 📉 Learning Rate after Epoch 13: 0.000103
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 14, Batch 0/3125: Loss 0.0308
# 🟢 Epoch 14, Batch 100/3125: Loss 0.0419
# 🟢 Epoch 14, Batch 200/3125: Loss 0.0373
# 🟢 Epoch 14, Batch 300/3125: Loss 0.0371
# 🟢 Epoch 14, Batch 400/3125: Loss 0.0396
# 🟢 Epoch 14, Batch 500/3125: Loss 0.0526
# 🟢 Epoch 14, Batch 600/3125: Loss 0.0381
# 🟢 Epoch 14, Batch 700/3125: Loss 0.0310
# 🟢 Epoch 14, Batch 800/3125: Loss 0.0346
# 🟢 Epoch 14, Batch 900/3125: Loss 0.0291
# 🟢 Epoch 14, Batch 1000/3125: Loss 0.0337
# 🟢 Epoch 14, Batch 1100/3125: Loss 0.0298
# 🟢 Epoch 14, Batch 1200/3125: Loss 0.0414
# 🟢 Epoch 14, Batch 1300/3125: Loss 0.0292
# 🟢 Epoch 14, Batch 1400/3125: Loss 0.0367
# 🟢 Epoch 14, Batch 1500/3125: Loss 0.0352
# 🟢 Epoch 14, Batch 1600/3125: Loss 0.0277
# 🟢 Epoch 14, Batch 1700/3125: Loss 0.0364
# 🟢 Epoch 14, Batch 1800/3125: Loss 0.0441
# 🟢 Epoch 14, Batch 1900/3125: Loss 0.0276
# 🟢 Epoch 14, Batch 2000/3125: Loss 0.0306
# 🟢 Epoch 14, Batch 2100/3125: Loss 0.0341
# 🟢 Epoch 14, Batch 2200/3125: Loss 0.0359
# 🟢 Epoch 14, Batch 2300/3125: Loss 0.0391
# 🟢 Epoch 14, Batch 2400/3125: Loss 0.0369
# 🟢 Epoch 14, Batch 2500/3125: Loss 0.0345
# 🟢 Epoch 14, Batch 2600/3125: Loss 0.0295
# 🟢 Epoch 14, Batch 2700/3125: Loss 0.0342
# 🟢 Epoch 14, Batch 2800/3125: Loss 0.0283
# 🟢 Epoch 14, Batch 2900/3125: Loss 0.0293
# 🟢 Epoch 14, Batch 3000/3125: Loss 0.0361
# 🟢 Epoch 14, Batch 3100/3125: Loss 0.0415
# ✅ Epoch 14 Done: Loss 106.1712, Train Acc: 0.3539, Time: 225.55s
# 📉 Learning Rate after Epoch 14: 0.000173
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 15, Batch 0/3125: Loss 0.0327
# 🟢 Epoch 15, Batch 100/3125: Loss 0.0289
# 🟢 Epoch 15, Batch 200/3125: Loss 0.0319
# 🟢 Epoch 15, Batch 300/3125: Loss 0.0360
# 🟢 Epoch 15, Batch 400/3125: Loss 0.0429
# 🟢 Epoch 15, Batch 500/3125: Loss 0.0305
# 🟢 Epoch 15, Batch 600/3125: Loss 0.0328
# 🟢 Epoch 15, Batch 700/3125: Loss 0.0340
# 🟢 Epoch 15, Batch 800/3125: Loss 0.0405
# 🟢 Epoch 15, Batch 900/3125: Loss 0.0317
# 🟢 Epoch 15, Batch 1000/3125: Loss 0.0271
# 🟢 Epoch 15, Batch 1100/3125: Loss 0.0251
# 🟢 Epoch 15, Batch 1200/3125: Loss 0.0316
# 🟢 Epoch 15, Batch 1300/3125: Loss 0.0379
# 🟢 Epoch 15, Batch 1400/3125: Loss 0.0378
# 🟢 Epoch 15, Batch 1500/3125: Loss 0.0322
# 🟢 Epoch 15, Batch 1600/3125: Loss 0.0417
# 🟢 Epoch 15, Batch 1700/3125: Loss 0.0407
# 🟢 Epoch 15, Batch 1800/3125: Loss 0.0378
# 🟢 Epoch 15, Batch 1900/3125: Loss 0.0375
# 🟢 Epoch 15, Batch 2000/3125: Loss 0.0298
# 🟢 Epoch 15, Batch 2100/3125: Loss 0.0239
# 🟢 Epoch 15, Batch 2200/3125: Loss 0.0318
# 🟢 Epoch 15, Batch 2300/3125: Loss 0.0358
# 🟢 Epoch 15, Batch 2400/3125: Loss 0.0372
# 🟢 Epoch 15, Batch 2500/3125: Loss 0.0377
# 🟢 Epoch 15, Batch 2600/3125: Loss 0.0368
# 🟢 Epoch 15, Batch 2700/3125: Loss 0.0376
# 🟢 Epoch 15, Batch 2800/3125: Loss 0.0271
# 🟢 Epoch 15, Batch 2900/3125: Loss 0.0346
# 🟢 Epoch 15, Batch 3000/3125: Loss 0.0368
# 🟢 Epoch 15, Batch 3100/3125: Loss 0.0335
# ✅ Epoch 15 Done: Loss 106.5810, Train Acc: 0.3532, Time: 225.23s
# 📉 Learning Rate after Epoch 15: 0.000250
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 16, Batch 0/3125: Loss 0.0335
# 🟢 Epoch 16, Batch 100/3125: Loss 0.0364
# 🟢 Epoch 16, Batch 200/3125: Loss 0.0291
# 🟢 Epoch 16, Batch 300/3125: Loss 0.0333
# 🟢 Epoch 16, Batch 400/3125: Loss 0.0319
# 🟢 Epoch 16, Batch 500/3125: Loss 0.0333
# 🟢 Epoch 16, Batch 600/3125: Loss 0.0420
# 🟢 Epoch 16, Batch 700/3125: Loss 0.0312
# 🟢 Epoch 16, Batch 800/3125: Loss 0.0345
# 🟢 Epoch 16, Batch 900/3125: Loss 0.0347
# 🟢 Epoch 16, Batch 1000/3125: Loss 0.0261
# 🟢 Epoch 16, Batch 1100/3125: Loss 0.0343
# 🟢 Epoch 16, Batch 1200/3125: Loss 0.0304
# 🟢 Epoch 16, Batch 1300/3125: Loss 0.0387
# 🟢 Epoch 16, Batch 1400/3125: Loss 0.0251
# 🟢 Epoch 16, Batch 1500/3125: Loss 0.0483
# 🟢 Epoch 16, Batch 1600/3125: Loss 0.0303
# 🟢 Epoch 16, Batch 1700/3125: Loss 0.0262
# 🟢 Epoch 16, Batch 1800/3125: Loss 0.0332
# 🟢 Epoch 16, Batch 1900/3125: Loss 0.0411
# 🟢 Epoch 16, Batch 2000/3125: Loss 0.0478
# 🟢 Epoch 16, Batch 2100/3125: Loss 0.0318
# 🟢 Epoch 16, Batch 2200/3125: Loss 0.0300
# 🟢 Epoch 16, Batch 2300/3125: Loss 0.0298
# 🟢 Epoch 16, Batch 2400/3125: Loss 0.0333
# 🟢 Epoch 16, Batch 2500/3125: Loss 0.0309
# 🟢 Epoch 16, Batch 2600/3125: Loss 0.0251
# 🟢 Epoch 16, Batch 2700/3125: Loss 0.0363
# 🟢 Epoch 16, Batch 2800/3125: Loss 0.0370
# 🟢 Epoch 16, Batch 2900/3125: Loss 0.0257
# 🟢 Epoch 16, Batch 3000/3125: Loss 0.0403
# 🟢 Epoch 16, Batch 3100/3125: Loss 0.0312
# ✅ Epoch 16 Done: Loss 105.8684, Train Acc: 0.3556, Time: 224.27s
# 📉 Learning Rate after Epoch 16: 0.000327
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 17, Batch 0/3125: Loss 0.0345
# 🟢 Epoch 17, Batch 100/3125: Loss 0.0437
# 🟢 Epoch 17, Batch 200/3125: Loss 0.0290
# 🟢 Epoch 17, Batch 300/3125: Loss 0.0277
# 🟢 Epoch 17, Batch 400/3125: Loss 0.0272
# 🟢 Epoch 17, Batch 500/3125: Loss 0.0273
# 🟢 Epoch 17, Batch 600/3125: Loss 0.0310
# 🟢 Epoch 17, Batch 700/3125: Loss 0.0301
# 🟢 Epoch 17, Batch 800/3125: Loss 0.0388
# 🟢 Epoch 17, Batch 900/3125: Loss 0.0312
# 🟢 Epoch 17, Batch 1000/3125: Loss 0.0430
# 🟢 Epoch 17, Batch 1100/3125: Loss 0.0345
# 🟢 Epoch 17, Batch 1200/3125: Loss 0.0259
# 🟢 Epoch 17, Batch 1300/3125: Loss 0.0316
# 🟢 Epoch 17, Batch 1400/3125: Loss 0.0354
# 🟢 Epoch 17, Batch 1500/3125: Loss 0.0400
# 🟢 Epoch 17, Batch 1600/3125: Loss 0.0231
# 🟢 Epoch 17, Batch 1700/3125: Loss 0.0317
# 🟢 Epoch 17, Batch 1800/3125: Loss 0.0409
# 🟢 Epoch 17, Batch 1900/3125: Loss 0.0307
# 🟢 Epoch 17, Batch 2000/3125: Loss 0.0361
# 🟢 Epoch 17, Batch 2100/3125: Loss 0.0337
# 🟢 Epoch 17, Batch 2200/3125: Loss 0.0304
# 🟢 Epoch 17, Batch 2300/3125: Loss 0.0360
# 🟢 Epoch 17, Batch 2400/3125: Loss 0.0305
# 🟢 Epoch 17, Batch 2500/3125: Loss 0.0315
# 🟢 Epoch 17, Batch 2600/3125: Loss 0.0364
# 🟢 Epoch 17, Batch 2700/3125: Loss 0.0359
# 🟢 Epoch 17, Batch 2800/3125: Loss 0.0371
# 🟢 Epoch 17, Batch 2900/3125: Loss 0.0409
# 🟢 Epoch 17, Batch 3000/3125: Loss 0.0279
# 🟢 Epoch 17, Batch 3100/3125: Loss 0.0343
# ✅ Epoch 17 Done: Loss 104.3486, Train Acc: 0.3603, Time: 223.93s
# 📉 Learning Rate after Epoch 17: 0.000397
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 18, Batch 0/3125: Loss 0.0366
# 🟢 Epoch 18, Batch 100/3125: Loss 0.0292
# 🟢 Epoch 18, Batch 200/3125: Loss 0.0279
# 🟢 Epoch 18, Batch 300/3125: Loss 0.0366
# 🟢 Epoch 18, Batch 400/3125: Loss 0.0309
# 🟢 Epoch 18, Batch 500/3125: Loss 0.0260
# 🟢 Epoch 18, Batch 600/3125: Loss 0.0325
# 🟢 Epoch 18, Batch 700/3125: Loss 0.0250
# 🟢 Epoch 18, Batch 800/3125: Loss 0.0420
# 🟢 Epoch 18, Batch 900/3125: Loss 0.0326
# 🟢 Epoch 18, Batch 1000/3125: Loss 0.0349
# 🟢 Epoch 18, Batch 1100/3125: Loss 0.0261
# 🟢 Epoch 18, Batch 1200/3125: Loss 0.0319
# 🟢 Epoch 18, Batch 1300/3125: Loss 0.0284
# 🟢 Epoch 18, Batch 1400/3125: Loss 0.0350
# 🟢 Epoch 18, Batch 1500/3125: Loss 0.0285
# 🟢 Epoch 18, Batch 1600/3125: Loss 0.0312
# 🟢 Epoch 18, Batch 1700/3125: Loss 0.0372
# 🟢 Epoch 18, Batch 1800/3125: Loss 0.0267
# 🟢 Epoch 18, Batch 1900/3125: Loss 0.0336
# 🟢 Epoch 18, Batch 2000/3125: Loss 0.0329
# 🟢 Epoch 18, Batch 2100/3125: Loss 0.0288
# 🟢 Epoch 18, Batch 2200/3125: Loss 0.0371
# 🟢 Epoch 18, Batch 2300/3125: Loss 0.0395
# 🟢 Epoch 18, Batch 2400/3125: Loss 0.0390
# 🟢 Epoch 18, Batch 2500/3125: Loss 0.0444
# 🟢 Epoch 18, Batch 2600/3125: Loss 0.0283
# 🟢 Epoch 18, Batch 2700/3125: Loss 0.0317
# 🟢 Epoch 18, Batch 2800/3125: Loss 0.0330
# 🟢 Epoch 18, Batch 2900/3125: Loss 0.0290
# 🟢 Epoch 18, Batch 3000/3125: Loss 0.0292
# 🟢 Epoch 18, Batch 3100/3125: Loss 0.0335
# ✅ Epoch 18 Done: Loss 104.6808, Train Acc: 0.3576, Time: 222.13s
# 📉 Learning Rate after Epoch 18: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 19, Batch 0/3125: Loss 0.0347
# 🟢 Epoch 19, Batch 100/3125: Loss 0.0278
# 🟢 Epoch 19, Batch 200/3125: Loss 0.0306
# 🟢 Epoch 19, Batch 300/3125: Loss 0.0318
# 🟢 Epoch 19, Batch 400/3125: Loss 0.0319
# 🟢 Epoch 19, Batch 500/3125: Loss 0.0316
# 🟢 Epoch 19, Batch 600/3125: Loss 0.0282
# 🟢 Epoch 19, Batch 700/3125: Loss 0.0317
# 🟢 Epoch 19, Batch 800/3125: Loss 0.0300
# 🟢 Epoch 19, Batch 900/3125: Loss 0.0313
# 🟢 Epoch 19, Batch 1000/3125: Loss 0.0296
# 🟢 Epoch 19, Batch 1100/3125: Loss 0.0322
# 🟢 Epoch 19, Batch 1200/3125: Loss 0.0440
# 🟢 Epoch 19, Batch 1300/3125: Loss 0.0296
# 🟢 Epoch 19, Batch 1400/3125: Loss 0.0398
# 🟢 Epoch 19, Batch 1500/3125: Loss 0.0351
# 🟢 Epoch 19, Batch 1600/3125: Loss 0.0400
# 🟢 Epoch 19, Batch 1700/3125: Loss 0.0245
# 🟢 Epoch 19, Batch 1800/3125: Loss 0.0325
# 🟢 Epoch 19, Batch 1900/3125: Loss 0.0391
# 🟢 Epoch 19, Batch 2000/3125: Loss 0.0341
# 🟢 Epoch 19, Batch 2100/3125: Loss 0.0390
# 🟢 Epoch 19, Batch 2200/3125: Loss 0.0401
# 🟢 Epoch 19, Batch 2300/3125: Loss 0.0235
# 🟢 Epoch 19, Batch 2400/3125: Loss 0.0309
# 🟢 Epoch 19, Batch 2500/3125: Loss 0.0452
# 🟢 Epoch 19, Batch 2600/3125: Loss 0.0433
# 🟢 Epoch 19, Batch 2700/3125: Loss 0.0335
# 🟢 Epoch 19, Batch 2800/3125: Loss 0.0267
# 🟢 Epoch 19, Batch 2900/3125: Loss 0.0354
# 🟢 Epoch 19, Batch 3000/3125: Loss 0.0392
# 🟢 Epoch 19, Batch 3100/3125: Loss 0.0337
# ✅ Epoch 19 Done: Loss 109.3475, Train Acc: 0.3447, Time: 222.26s
# 📉 Learning Rate after Epoch 19: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 20, Batch 0/3125: Loss 0.0319
# 🟢 Epoch 20, Batch 100/3125: Loss 0.0399
# 🟢 Epoch 20, Batch 200/3125: Loss 0.0395
# 🟢 Epoch 20, Batch 300/3125: Loss 0.0348
# 🟢 Epoch 20, Batch 400/3125: Loss 0.0315
# 🟢 Epoch 20, Batch 500/3125: Loss 0.0390
# 🟢 Epoch 20, Batch 600/3125: Loss 0.0401
# 🟢 Epoch 20, Batch 700/3125: Loss 0.0344
# 🟢 Epoch 20, Batch 800/3125: Loss 0.0403
# 🟢 Epoch 20, Batch 900/3125: Loss 0.0381
# 🟢 Epoch 20, Batch 1000/3125: Loss 0.0298
# 🟢 Epoch 20, Batch 1100/3125: Loss 0.0299
# 🟢 Epoch 20, Batch 1200/3125: Loss 0.0425
# 🟢 Epoch 20, Batch 1300/3125: Loss 0.0318
# 🟢 Epoch 20, Batch 1400/3125: Loss 0.0405
# 🟢 Epoch 20, Batch 1500/3125: Loss 0.0408
# 🟢 Epoch 20, Batch 1600/3125: Loss 0.0374
# 🟢 Epoch 20, Batch 1700/3125: Loss 0.0297
# 🟢 Epoch 20, Batch 1800/3125: Loss 0.0438
# 🟢 Epoch 20, Batch 1900/3125: Loss 0.0366
# 🟢 Epoch 20, Batch 2000/3125: Loss 0.0227
# 🟢 Epoch 20, Batch 2100/3125: Loss 0.0342
# 🟢 Epoch 20, Batch 2200/3125: Loss 0.0303
# 🟢 Epoch 20, Batch 2300/3125: Loss 0.0353
# 🟢 Epoch 20, Batch 2400/3125: Loss 0.0227
# 🟢 Epoch 20, Batch 2500/3125: Loss 0.0286
# 🟢 Epoch 20, Batch 2600/3125: Loss 0.0352
# 🟢 Epoch 20, Batch 2700/3125: Loss 0.0391
# 🟢 Epoch 20, Batch 2800/3125: Loss 0.0390
# 🟢 Epoch 20, Batch 2900/3125: Loss 0.0273
# 🟢 Epoch 20, Batch 3000/3125: Loss 0.0347
# 🟢 Epoch 20, Batch 3100/3125: Loss 0.0362
# ✅ Epoch 20 Done: Loss 109.1834, Train Acc: 0.3498, Time: 223.88s
# 📉 Learning Rate after Epoch 20: 0.000500
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 21, Batch 0/3125: Loss 0.0405
# 🟢 Epoch 21, Batch 100/3125: Loss 0.0426
# 🟢 Epoch 21, Batch 200/3125: Loss 0.0410
# 🟢 Epoch 21, Batch 300/3125: Loss 0.0380
# 🟢 Epoch 21, Batch 400/3125: Loss 0.0311
# 🟢 Epoch 21, Batch 500/3125: Loss 0.0322
# 🟢 Epoch 21, Batch 600/3125: Loss 0.0308
# 🟢 Epoch 21, Batch 700/3125: Loss 0.0398
# 🟢 Epoch 21, Batch 800/3125: Loss 0.0419
# 🟢 Epoch 21, Batch 900/3125: Loss 0.0382
# 🟢 Epoch 21, Batch 1000/3125: Loss 0.0431
# 🟢 Epoch 21, Batch 1100/3125: Loss 0.0394
# 🟢 Epoch 21, Batch 1200/3125: Loss 0.0355
# 🟢 Epoch 21, Batch 1300/3125: Loss 0.0270
# 🟢 Epoch 21, Batch 1400/3125: Loss 0.0494
# 🟢 Epoch 21, Batch 1500/3125: Loss 0.0347
# 🟢 Epoch 21, Batch 1600/3125: Loss 0.0357
# 🟢 Epoch 21, Batch 1700/3125: Loss 0.0383
# 🟢 Epoch 21, Batch 1800/3125: Loss 0.0326
# 🟢 Epoch 21, Batch 1900/3125: Loss 0.0313
# 🟢 Epoch 21, Batch 2000/3125: Loss 0.0309
# 🟢 Epoch 21, Batch 2100/3125: Loss 0.0374
# 🟢 Epoch 21, Batch 2200/3125: Loss 0.0340
# 🟢 Epoch 21, Batch 2300/3125: Loss 0.0306
# 🟢 Epoch 21, Batch 2400/3125: Loss 0.0394
# 🟢 Epoch 21, Batch 2500/3125: Loss 0.0410
# 🟢 Epoch 21, Batch 2600/3125: Loss 0.0350
# 🟢 Epoch 21, Batch 2700/3125: Loss 0.0300
# 🟢 Epoch 21, Batch 2800/3125: Loss 0.0309
# 🟢 Epoch 21, Batch 2900/3125: Loss 0.0352
# 🟢 Epoch 21, Batch 3000/3125: Loss 0.0389
# 🟢 Epoch 21, Batch 3100/3125: Loss 0.0283
# ✅ Epoch 21 Done: Loss 108.4419, Train Acc: 0.3494, Time: 223.69s
# 📉 Learning Rate after Epoch 21: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 22, Batch 0/3125: Loss 0.0433
# 🟢 Epoch 22, Batch 100/3125: Loss 0.0283
# 🟢 Epoch 22, Batch 200/3125: Loss 0.0363
# 🟢 Epoch 22, Batch 300/3125: Loss 0.0318
# 🟢 Epoch 22, Batch 400/3125: Loss 0.0323
# 🟢 Epoch 22, Batch 500/3125: Loss 0.0335
# 🟢 Epoch 22, Batch 600/3125: Loss 0.0222
# 🟢 Epoch 22, Batch 700/3125: Loss 0.0335
# 🟢 Epoch 22, Batch 800/3125: Loss 0.0360
# 🟢 Epoch 22, Batch 900/3125: Loss 0.0268
# 🟢 Epoch 22, Batch 1000/3125: Loss 0.0381
# 🟢 Epoch 22, Batch 1100/3125: Loss 0.0286
# 🟢 Epoch 22, Batch 1200/3125: Loss 0.0338
# 🟢 Epoch 22, Batch 1300/3125: Loss 0.0321
# 🟢 Epoch 22, Batch 1400/3125: Loss 0.0300
# 🟢 Epoch 22, Batch 1500/3125: Loss 0.0338
# 🟢 Epoch 22, Batch 1600/3125: Loss 0.0319
# 🟢 Epoch 22, Batch 1700/3125: Loss 0.0433
# 🟢 Epoch 22, Batch 1800/3125: Loss 0.0262
# 🟢 Epoch 22, Batch 1900/3125: Loss 0.0341
# 🟢 Epoch 22, Batch 2000/3125: Loss 0.0277
# 🟢 Epoch 22, Batch 2100/3125: Loss 0.0198
# 🟢 Epoch 22, Batch 2200/3125: Loss 0.0361
# 🟢 Epoch 22, Batch 2300/3125: Loss 0.0395
# 🟢 Epoch 22, Batch 2400/3125: Loss 0.0312
# 🟢 Epoch 22, Batch 2500/3125: Loss 0.0410
# 🟢 Epoch 22, Batch 2600/3125: Loss 0.0276
# 🟢 Epoch 22, Batch 2700/3125: Loss 0.0463
# 🟢 Epoch 22, Batch 2800/3125: Loss 0.0266
# 🟢 Epoch 22, Batch 2900/3125: Loss 0.0334
# 🟢 Epoch 22, Batch 3000/3125: Loss 0.0387
# 🟢 Epoch 22, Batch 3100/3125: Loss 0.0346
# ✅ Epoch 22 Done: Loss 106.3644, Train Acc: 0.3527, Time: 223.03s
# 📉 Learning Rate after Epoch 22: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 23, Batch 0/3125: Loss 0.0386
# 🟢 Epoch 23, Batch 100/3125: Loss 0.0340
# 🟢 Epoch 23, Batch 200/3125: Loss 0.0396
# 🟢 Epoch 23, Batch 300/3125: Loss 0.0317
# 🟢 Epoch 23, Batch 400/3125: Loss 0.0275
# 🟢 Epoch 23, Batch 500/3125: Loss 0.0355
# 🟢 Epoch 23, Batch 600/3125: Loss 0.0396
# 🟢 Epoch 23, Batch 700/3125: Loss 0.0341
# 🟢 Epoch 23, Batch 800/3125: Loss 0.0403
# 🟢 Epoch 23, Batch 900/3125: Loss 0.0404
# 🟢 Epoch 23, Batch 1000/3125: Loss 0.0303
# 🟢 Epoch 23, Batch 1100/3125: Loss 0.0352
# 🟢 Epoch 23, Batch 1200/3125: Loss 0.0408
# 🟢 Epoch 23, Batch 1300/3125: Loss 0.0262
# 🟢 Epoch 23, Batch 1400/3125: Loss 0.0419
# 🟢 Epoch 23, Batch 1500/3125: Loss 0.0377
# 🟢 Epoch 23, Batch 1600/3125: Loss 0.0381
# 🟢 Epoch 23, Batch 1700/3125: Loss 0.0303
# 🟢 Epoch 23, Batch 1800/3125: Loss 0.0247
# 🟢 Epoch 23, Batch 1900/3125: Loss 0.0312
# 🟢 Epoch 23, Batch 2000/3125: Loss 0.0320
# 🟢 Epoch 23, Batch 2100/3125: Loss 0.0332
# 🟢 Epoch 23, Batch 2200/3125: Loss 0.0421
# 🟢 Epoch 23, Batch 2300/3125: Loss 0.0296
# 🟢 Epoch 23, Batch 2400/3125: Loss 0.0260
# 🟢 Epoch 23, Batch 2500/3125: Loss 0.0321
# 🟢 Epoch 23, Batch 2600/3125: Loss 0.0362
# 🟢 Epoch 23, Batch 2700/3125: Loss 0.0352
# 🟢 Epoch 23, Batch 2800/3125: Loss 0.0353
# 🟢 Epoch 23, Batch 2900/3125: Loss 0.0340
# 🟢 Epoch 23, Batch 3000/3125: Loss 0.0305
# 🟢 Epoch 23, Batch 3100/3125: Loss 0.0274
# ✅ Epoch 23 Done: Loss 104.4927, Train Acc: 0.3587, Time: 222.48s
# 📉 Learning Rate after Epoch 23: 0.000397
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 24, Batch 0/3125: Loss 0.0244
# 🟢 Epoch 24, Batch 100/3125: Loss 0.0406
# 🟢 Epoch 24, Batch 200/3125: Loss 0.0296
# 🟢 Epoch 24, Batch 300/3125: Loss 0.0322
# 🟢 Epoch 24, Batch 400/3125: Loss 0.0359
# 🟢 Epoch 24, Batch 500/3125: Loss 0.0414
# 🟢 Epoch 24, Batch 600/3125: Loss 0.0278
# 🟢 Epoch 24, Batch 700/3125: Loss 0.0231
# 🟢 Epoch 24, Batch 800/3125: Loss 0.0269
# 🟢 Epoch 24, Batch 900/3125: Loss 0.0294
# 🟢 Epoch 24, Batch 1000/3125: Loss 0.0341
# 🟢 Epoch 24, Batch 1100/3125: Loss 0.0259
# 🟢 Epoch 24, Batch 1200/3125: Loss 0.0311
# 🟢 Epoch 24, Batch 1300/3125: Loss 0.0296
# 🟢 Epoch 24, Batch 1400/3125: Loss 0.0442
# 🟢 Epoch 24, Batch 1500/3125: Loss 0.0291
# 🟢 Epoch 24, Batch 1600/3125: Loss 0.0370
# 🟢 Epoch 24, Batch 1700/3125: Loss 0.0271
# 🟢 Epoch 24, Batch 1800/3125: Loss 0.0419
# 🟢 Epoch 24, Batch 1900/3125: Loss 0.0383
# 🟢 Epoch 24, Batch 2000/3125: Loss 0.0329
# 🟢 Epoch 24, Batch 2100/3125: Loss 0.0181
# 🟢 Epoch 24, Batch 2200/3125: Loss 0.0352
# 🟢 Epoch 24, Batch 2300/3125: Loss 0.0294
# 🟢 Epoch 24, Batch 2400/3125: Loss 0.0292
# 🟢 Epoch 24, Batch 2500/3125: Loss 0.0325
# 🟢 Epoch 24, Batch 2600/3125: Loss 0.0258
# 🟢 Epoch 24, Batch 2700/3125: Loss 0.0316
# 🟢 Epoch 24, Batch 2800/3125: Loss 0.0269
# 🟢 Epoch 24, Batch 2900/3125: Loss 0.0299
# 🟢 Epoch 24, Batch 3000/3125: Loss 0.0335
# 🟢 Epoch 24, Batch 3100/3125: Loss 0.0301
# ✅ Epoch 24 Done: Loss 98.7084, Train Acc: 0.3755, Time: 224.02s
# 📉 Learning Rate after Epoch 24: 0.000327
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 25, Batch 0/3125: Loss 0.0304
# 🟢 Epoch 25, Batch 100/3125: Loss 0.0290
# 🟢 Epoch 25, Batch 200/3125: Loss 0.0331
# 🟢 Epoch 25, Batch 300/3125: Loss 0.0289
# 🟢 Epoch 25, Batch 400/3125: Loss 0.0398
# 🟢 Epoch 25, Batch 500/3125: Loss 0.0322
# 🟢 Epoch 25, Batch 600/3125: Loss 0.0326
# 🟢 Epoch 25, Batch 700/3125: Loss 0.0421
# 🟢 Epoch 25, Batch 800/3125: Loss 0.0316
# 🟢 Epoch 25, Batch 900/3125: Loss 0.0309
# 🟢 Epoch 25, Batch 1000/3125: Loss 0.0297
# 🟢 Epoch 25, Batch 1100/3125: Loss 0.0214
# 🟢 Epoch 25, Batch 1200/3125: Loss 0.0301
# 🟢 Epoch 25, Batch 1300/3125: Loss 0.0307
# 🟢 Epoch 25, Batch 1400/3125: Loss 0.0358
# 🟢 Epoch 25, Batch 1500/3125: Loss 0.0265
# 🟢 Epoch 25, Batch 1600/3125: Loss 0.0376
# 🟢 Epoch 25, Batch 1700/3125: Loss 0.0299
# 🟢 Epoch 25, Batch 1800/3125: Loss 0.0368
# 🟢 Epoch 25, Batch 1900/3125: Loss 0.0328
# 🟢 Epoch 25, Batch 2000/3125: Loss 0.0293
# 🟢 Epoch 25, Batch 2100/3125: Loss 0.0203
# 🟢 Epoch 25, Batch 2200/3125: Loss 0.0229
# 🟢 Epoch 25, Batch 2300/3125: Loss 0.0338
# 🟢 Epoch 25, Batch 2400/3125: Loss 0.0290
# 🟢 Epoch 25, Batch 2500/3125: Loss 0.0307
# 🟢 Epoch 25, Batch 2600/3125: Loss 0.0320
# 🟢 Epoch 25, Batch 2700/3125: Loss 0.0336
# 🟢 Epoch 25, Batch 2800/3125: Loss 0.0177
# 🟢 Epoch 25, Batch 2900/3125: Loss 0.0226
# 🟢 Epoch 25, Batch 3000/3125: Loss 0.0202
# 🟢 Epoch 25, Batch 3100/3125: Loss 0.0262
# ✅ Epoch 25 Done: Loss 96.2717, Train Acc: 0.3847, Time: 224.41s
# 📉 Learning Rate after Epoch 25: 0.000250
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 26, Batch 0/3125: Loss 0.0378
# 🟢 Epoch 26, Batch 100/3125: Loss 0.0312
# 🟢 Epoch 26, Batch 200/3125: Loss 0.0329
# 🟢 Epoch 26, Batch 300/3125: Loss 0.0335
# 🟢 Epoch 26, Batch 400/3125: Loss 0.0279
# 🟢 Epoch 26, Batch 500/3125: Loss 0.0421
# 🟢 Epoch 26, Batch 600/3125: Loss 0.0410
# 🟢 Epoch 26, Batch 700/3125: Loss 0.0332
# 🟢 Epoch 26, Batch 800/3125: Loss 0.0320
# 🟢 Epoch 26, Batch 900/3125: Loss 0.0275
# 🟢 Epoch 26, Batch 1000/3125: Loss 0.0301
# 🟢 Epoch 26, Batch 1100/3125: Loss 0.0361
# 🟢 Epoch 26, Batch 1200/3125: Loss 0.0403
# 🟢 Epoch 26, Batch 1300/3125: Loss 0.0273
# 🟢 Epoch 26, Batch 1400/3125: Loss 0.0329
# 🟢 Epoch 26, Batch 1500/3125: Loss 0.0309
# 🟢 Epoch 26, Batch 1600/3125: Loss 0.0308
# 🟢 Epoch 26, Batch 1700/3125: Loss 0.0328
# 🟢 Epoch 26, Batch 1800/3125: Loss 0.0327
# 🟢 Epoch 26, Batch 1900/3125: Loss 0.0232
# 🟢 Epoch 26, Batch 2000/3125: Loss 0.0320
# 🟢 Epoch 26, Batch 2100/3125: Loss 0.0212
# 🟢 Epoch 26, Batch 2200/3125: Loss 0.0274
# 🟢 Epoch 26, Batch 2300/3125: Loss 0.0343
# 🟢 Epoch 26, Batch 2400/3125: Loss 0.0307
# 🟢 Epoch 26, Batch 2500/3125: Loss 0.0371
# 🟢 Epoch 26, Batch 2600/3125: Loss 0.0329
# 🟢 Epoch 26, Batch 2700/3125: Loss 0.0395
# 🟢 Epoch 26, Batch 2800/3125: Loss 0.0356
# 🟢 Epoch 26, Batch 2900/3125: Loss 0.0306
# 🟢 Epoch 26, Batch 3000/3125: Loss 0.0228
# 🟢 Epoch 26, Batch 3100/3125: Loss 0.0207
# ✅ Epoch 26 Done: Loss 94.8165, Train Acc: 0.3908, Time: 223.92s
# 📉 Learning Rate after Epoch 26: 0.000173
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 27, Batch 0/3125: Loss 0.0300
# 🟢 Epoch 27, Batch 100/3125: Loss 0.0238
# 🟢 Epoch 27, Batch 200/3125: Loss 0.0237
# 🟢 Epoch 27, Batch 300/3125: Loss 0.0256
# 🟢 Epoch 27, Batch 400/3125: Loss 0.0282
# 🟢 Epoch 27, Batch 500/3125: Loss 0.0310
# 🟢 Epoch 27, Batch 600/3125: Loss 0.0272
# 🟢 Epoch 27, Batch 700/3125: Loss 0.0304
# 🟢 Epoch 27, Batch 800/3125: Loss 0.0363
# 🟢 Epoch 27, Batch 900/3125: Loss 0.0359
# 🟢 Epoch 27, Batch 1000/3125: Loss 0.0192
# 🟢 Epoch 27, Batch 1100/3125: Loss 0.0241
# 🟢 Epoch 27, Batch 1200/3125: Loss 0.0216
# 🟢 Epoch 27, Batch 1300/3125: Loss 0.0272
# 🟢 Epoch 27, Batch 1400/3125: Loss 0.0340
# 🟢 Epoch 27, Batch 1500/3125: Loss 0.0402
# 🟢 Epoch 27, Batch 1600/3125: Loss 0.0386
# 🟢 Epoch 27, Batch 1700/3125: Loss 0.0323
# 🟢 Epoch 27, Batch 1800/3125: Loss 0.0296
# 🟢 Epoch 27, Batch 1900/3125: Loss 0.0289
# 🟢 Epoch 27, Batch 2000/3125: Loss 0.0175
# 🟢 Epoch 27, Batch 2100/3125: Loss 0.0240
# 🟢 Epoch 27, Batch 2200/3125: Loss 0.0261
# 🟢 Epoch 27, Batch 2300/3125: Loss 0.0336
# 🟢 Epoch 27, Batch 2400/3125: Loss 0.0312
# 🟢 Epoch 27, Batch 2500/3125: Loss 0.0277
# 🟢 Epoch 27, Batch 2600/3125: Loss 0.0312
# 🟢 Epoch 27, Batch 2700/3125: Loss 0.0206
# 🟢 Epoch 27, Batch 2800/3125: Loss 0.0215
# 🟢 Epoch 27, Batch 2900/3125: Loss 0.0277
# 🟢 Epoch 27, Batch 3000/3125: Loss 0.0392
# 🟢 Epoch 27, Batch 3100/3125: Loss 0.0241
# ✅ Epoch 27 Done: Loss 93.4451, Train Acc: 0.3954, Time: 224.75s
# 📉 Learning Rate after Epoch 27: 0.000103
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 28, Batch 0/3125: Loss 0.0271
# 🟢 Epoch 28, Batch 100/3125: Loss 0.0277
# 🟢 Epoch 28, Batch 200/3125: Loss 0.0329
# 🟢 Epoch 28, Batch 300/3125: Loss 0.0367
# 🟢 Epoch 28, Batch 400/3125: Loss 0.0338
# 🟢 Epoch 28, Batch 500/3125: Loss 0.0365
# 🟢 Epoch 28, Batch 600/3125: Loss 0.0208
# 🟢 Epoch 28, Batch 700/3125: Loss 0.0260
# 🟢 Epoch 28, Batch 800/3125: Loss 0.0308
# 🟢 Epoch 28, Batch 900/3125: Loss 0.0323
# 🟢 Epoch 28, Batch 1000/3125: Loss 0.0227
# 🟢 Epoch 28, Batch 1100/3125: Loss 0.0339
# 🟢 Epoch 28, Batch 1200/3125: Loss 0.0236
# 🟢 Epoch 28, Batch 1300/3125: Loss 0.0216
# 🟢 Epoch 28, Batch 1400/3125: Loss 0.0360
# 🟢 Epoch 28, Batch 1500/3125: Loss 0.0283
# 🟢 Epoch 28, Batch 1600/3125: Loss 0.0311
# 🟢 Epoch 28, Batch 1700/3125: Loss 0.0277
# 🟢 Epoch 28, Batch 1800/3125: Loss 0.0343
# 🟢 Epoch 28, Batch 1900/3125: Loss 0.0410
# 🟢 Epoch 28, Batch 2000/3125: Loss 0.0355
# 🟢 Epoch 28, Batch 2100/3125: Loss 0.0235
# 🟢 Epoch 28, Batch 2200/3125: Loss 0.0266
# 🟢 Epoch 28, Batch 2300/3125: Loss 0.0239
# 🟢 Epoch 28, Batch 2400/3125: Loss 0.0284
# 🟢 Epoch 28, Batch 2500/3125: Loss 0.0252
# 🟢 Epoch 28, Batch 2600/3125: Loss 0.0359
# 🟢 Epoch 28, Batch 2700/3125: Loss 0.0335
# 🟢 Epoch 28, Batch 2800/3125: Loss 0.0309
# 🟢 Epoch 28, Batch 2900/3125: Loss 0.0268
# 🟢 Epoch 28, Batch 3000/3125: Loss 0.0284
# 🟢 Epoch 28, Batch 3100/3125: Loss 0.0309
# ✅ Epoch 28 Done: Loss 91.8285, Train Acc: 0.4024, Time: 225.19s
# 📉 Learning Rate after Epoch 28: 0.000048
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 29, Batch 0/3125: Loss 0.0412
# 🟢 Epoch 29, Batch 100/3125: Loss 0.0371
# 🟢 Epoch 29, Batch 200/3125: Loss 0.0266
# 🟢 Epoch 29, Batch 300/3125: Loss 0.0341
# 🟢 Epoch 29, Batch 400/3125: Loss 0.0314
# 🟢 Epoch 29, Batch 500/3125: Loss 0.0298
# 🟢 Epoch 29, Batch 600/3125: Loss 0.0239
# 🟢 Epoch 29, Batch 700/3125: Loss 0.0367
# 🟢 Epoch 29, Batch 800/3125: Loss 0.0258
# 🟢 Epoch 29, Batch 900/3125: Loss 0.0290
# 🟢 Epoch 29, Batch 1000/3125: Loss 0.0279
# 🟢 Epoch 29, Batch 1100/3125: Loss 0.0274
# 🟢 Epoch 29, Batch 1200/3125: Loss 0.0309
# 🟢 Epoch 29, Batch 1300/3125: Loss 0.0222
# 🟢 Epoch 29, Batch 1400/3125: Loss 0.0210
# 🟢 Epoch 29, Batch 1500/3125: Loss 0.0297
# 🟢 Epoch 29, Batch 1600/3125: Loss 0.0391
# 🟢 Epoch 29, Batch 1700/3125: Loss 0.0216
# 🟢 Epoch 29, Batch 1800/3125: Loss 0.0295
# 🟢 Epoch 29, Batch 1900/3125: Loss 0.0385
# 🟢 Epoch 29, Batch 2000/3125: Loss 0.0277
# 🟢 Epoch 29, Batch 2100/3125: Loss 0.0302
# 🟢 Epoch 29, Batch 2200/3125: Loss 0.0243
# 🟢 Epoch 29, Batch 2300/3125: Loss 0.0303
# 🟢 Epoch 29, Batch 2400/3125: Loss 0.0332
# 🟢 Epoch 29, Batch 2500/3125: Loss 0.0432
# 🟢 Epoch 29, Batch 2600/3125: Loss 0.0325
# 🟢 Epoch 29, Batch 2700/3125: Loss 0.0287
# 🟢 Epoch 29, Batch 2800/3125: Loss 0.0255
# 🟢 Epoch 29, Batch 2900/3125: Loss 0.0341
# 🟢 Epoch 29, Batch 3000/3125: Loss 0.0323
# 🟢 Epoch 29, Batch 3100/3125: Loss 0.0381
# ✅ Epoch 29 Done: Loss 90.8845, Train Acc: 0.4063, Time: 225.28s
# 📉 Learning Rate after Epoch 29: 0.000012
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 30, Batch 0/3125: Loss 0.0270
# 🟢 Epoch 30, Batch 100/3125: Loss 0.0309
# 🟢 Epoch 30, Batch 200/3125: Loss 0.0303
# 🟢 Epoch 30, Batch 300/3125: Loss 0.0284
# 🟢 Epoch 30, Batch 400/3125: Loss 0.0250
# 🟢 Epoch 30, Batch 500/3125: Loss 0.0378
# 🟢 Epoch 30, Batch 600/3125: Loss 0.0279
# 🟢 Epoch 30, Batch 700/3125: Loss 0.0178
# 🟢 Epoch 30, Batch 800/3125: Loss 0.0311
# 🟢 Epoch 30, Batch 900/3125: Loss 0.0236
# 🟢 Epoch 30, Batch 1000/3125: Loss 0.0230
# 🟢 Epoch 30, Batch 1100/3125: Loss 0.0310
# 🟢 Epoch 30, Batch 1200/3125: Loss 0.0430
# 🟢 Epoch 30, Batch 1300/3125: Loss 0.0307
# 🟢 Epoch 30, Batch 1400/3125: Loss 0.0260
# 🟢 Epoch 30, Batch 1500/3125: Loss 0.0261
# 🟢 Epoch 30, Batch 1600/3125: Loss 0.0340
# 🟢 Epoch 30, Batch 1700/3125: Loss 0.0309
# 🟢 Epoch 30, Batch 1800/3125: Loss 0.0282
# 🟢 Epoch 30, Batch 1900/3125: Loss 0.0303
# 🟢 Epoch 30, Batch 2000/3125: Loss 0.0374
# 🟢 Epoch 30, Batch 2100/3125: Loss 0.0245
# 🟢 Epoch 30, Batch 2200/3125: Loss 0.0350
# 🟢 Epoch 30, Batch 2300/3125: Loss 0.0335
# 🟢 Epoch 30, Batch 2400/3125: Loss 0.0284
# 🟢 Epoch 30, Batch 2500/3125: Loss 0.0341
# 🟢 Epoch 30, Batch 2600/3125: Loss 0.0234
# 🟢 Epoch 30, Batch 2700/3125: Loss 0.0338
# 🟢 Epoch 30, Batch 2800/3125: Loss 0.0367
# 🟢 Epoch 30, Batch 2900/3125: Loss 0.0291
# 🟢 Epoch 30, Batch 3000/3125: Loss 0.0331
# 🟢 Epoch 30, Batch 3100/3125: Loss 0.0244
# ✅ Epoch 30 Done: Loss 90.3442, Train Acc: 0.4078, Time: 223.82s
# 📉 Learning Rate after Epoch 30: 0.000000
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 31, Batch 0/3125: Loss 0.0347
# 🟢 Epoch 31, Batch 100/3125: Loss 0.0206
# 🟢 Epoch 31, Batch 200/3125: Loss 0.0218
# 🟢 Epoch 31, Batch 300/3125: Loss 0.0212
# 🟢 Epoch 31, Batch 400/3125: Loss 0.0356
# 🟢 Epoch 31, Batch 500/3125: Loss 0.0358
# 🟢 Epoch 31, Batch 600/3125: Loss 0.0246
# 🟢 Epoch 31, Batch 700/3125: Loss 0.0267
# 🟢 Epoch 31, Batch 800/3125: Loss 0.0382
# 🟢 Epoch 31, Batch 900/3125: Loss 0.0239
# 🟢 Epoch 31, Batch 1000/3125: Loss 0.0262
# 🟢 Epoch 31, Batch 1100/3125: Loss 0.0348
# 🟢 Epoch 31, Batch 1200/3125: Loss 0.0336
# 🟢 Epoch 31, Batch 1300/3125: Loss 0.0244
# 🟢 Epoch 31, Batch 1400/3125: Loss 0.0299
# 🟢 Epoch 31, Batch 1500/3125: Loss 0.0249
# 🟢 Epoch 31, Batch 1600/3125: Loss 0.0332
# 🟢 Epoch 31, Batch 1700/3125: Loss 0.0201
# 🟢 Epoch 31, Batch 1800/3125: Loss 0.0278
# 🟢 Epoch 31, Batch 1900/3125: Loss 0.0369
# 🟢 Epoch 31, Batch 2000/3125: Loss 0.0293
# 🟢 Epoch 31, Batch 2100/3125: Loss 0.0319
# 🟢 Epoch 31, Batch 2200/3125: Loss 0.0258
# 🟢 Epoch 31, Batch 2300/3125: Loss 0.0334
# 🟢 Epoch 31, Batch 2400/3125: Loss 0.0158
# 🟢 Epoch 31, Batch 2500/3125: Loss 0.0292
# 🟢 Epoch 31, Batch 2600/3125: Loss 0.0358
# 🟢 Epoch 31, Batch 2700/3125: Loss 0.0341
# 🟢 Epoch 31, Batch 2800/3125: Loss 0.0239
# 🟢 Epoch 31, Batch 2900/3125: Loss 0.0273
# 🟢 Epoch 31, Batch 3000/3125: Loss 0.0327
# 🟢 Epoch 31, Batch 3100/3125: Loss 0.0301
# ✅ Epoch 31 Done: Loss 90.1213, Train Acc: 0.4079, Time: 224.55s
# 📉 Learning Rate after Epoch 31: 0.000012
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 32, Batch 0/3125: Loss 0.0290
# 🟢 Epoch 32, Batch 100/3125: Loss 0.0292
# 🟢 Epoch 32, Batch 200/3125: Loss 0.0295
# 🟢 Epoch 32, Batch 300/3125: Loss 0.0314
# 🟢 Epoch 32, Batch 400/3125: Loss 0.0298
# 🟢 Epoch 32, Batch 500/3125: Loss 0.0309
# 🟢 Epoch 32, Batch 600/3125: Loss 0.0302
# 🟢 Epoch 32, Batch 700/3125: Loss 0.0249
# 🟢 Epoch 32, Batch 800/3125: Loss 0.0260
# 🟢 Epoch 32, Batch 900/3125: Loss 0.0446
# 🟢 Epoch 32, Batch 1000/3125: Loss 0.0360
# 🟢 Epoch 32, Batch 1100/3125: Loss 0.0206
# 🟢 Epoch 32, Batch 1200/3125: Loss 0.0304
# 🟢 Epoch 32, Batch 1300/3125: Loss 0.0227
# 🟢 Epoch 32, Batch 1400/3125: Loss 0.0313
# 🟢 Epoch 32, Batch 1500/3125: Loss 0.0252
# 🟢 Epoch 32, Batch 1600/3125: Loss 0.0194
# 🟢 Epoch 32, Batch 1700/3125: Loss 0.0291
# 🟢 Epoch 32, Batch 1800/3125: Loss 0.0380
# 🟢 Epoch 32, Batch 1900/3125: Loss 0.0367
# 🟢 Epoch 32, Batch 2000/3125: Loss 0.0303
# 🟢 Epoch 32, Batch 2100/3125: Loss 0.0340
# 🟢 Epoch 32, Batch 2200/3125: Loss 0.0333
# 🟢 Epoch 32, Batch 2300/3125: Loss 0.0318
# 🟢 Epoch 32, Batch 2400/3125: Loss 0.0230
# 🟢 Epoch 32, Batch 2500/3125: Loss 0.0280
# 🟢 Epoch 32, Batch 2600/3125: Loss 0.0285
# 🟢 Epoch 32, Batch 2700/3125: Loss 0.0204
# 🟢 Epoch 32, Batch 2800/3125: Loss 0.0307
# 🟢 Epoch 32, Batch 2900/3125: Loss 0.0310
# 🟢 Epoch 32, Batch 3000/3125: Loss 0.0305
# 🟢 Epoch 32, Batch 3100/3125: Loss 0.0212
# ✅ Epoch 32 Done: Loss 90.4278, Train Acc: 0.4089, Time: 224.13s
# 📉 Learning Rate after Epoch 32: 0.000048
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 33, Batch 0/3125: Loss 0.0230
# 🟢 Epoch 33, Batch 100/3125: Loss 0.0230
# 🟢 Epoch 33, Batch 200/3125: Loss 0.0347
# 🟢 Epoch 33, Batch 300/3125: Loss 0.0241
# 🟢 Epoch 33, Batch 400/3125: Loss 0.0382
# 🟢 Epoch 33, Batch 500/3125: Loss 0.0209
# 🟢 Epoch 33, Batch 600/3125: Loss 0.0436
# 🟢 Epoch 33, Batch 700/3125: Loss 0.0180
# 🟢 Epoch 33, Batch 800/3125: Loss 0.0167
# 🟢 Epoch 33, Batch 900/3125: Loss 0.0265
# 🟢 Epoch 33, Batch 1000/3125: Loss 0.0378
# 🟢 Epoch 33, Batch 1100/3125: Loss 0.0228
# 🟢 Epoch 33, Batch 1200/3125: Loss 0.0351
# 🟢 Epoch 33, Batch 1300/3125: Loss 0.0366
# 🟢 Epoch 33, Batch 1400/3125: Loss 0.0314
# 🟢 Epoch 33, Batch 1500/3125: Loss 0.0267
# 🟢 Epoch 33, Batch 1600/3125: Loss 0.0285
# 🟢 Epoch 33, Batch 1700/3125: Loss 0.0292
# 🟢 Epoch 33, Batch 1800/3125: Loss 0.0377
# 🟢 Epoch 33, Batch 1900/3125: Loss 0.0326
# 🟢 Epoch 33, Batch 2000/3125: Loss 0.0190
# 🟢 Epoch 33, Batch 2100/3125: Loss 0.0357
# 🟢 Epoch 33, Batch 2200/3125: Loss 0.0207
# ...
# 🟢 Epoch 38, Batch 1200/3125: Loss 0.0308
# 🟢 Epoch 38, Batch 1300/3125: Loss 0.0255
# 🟢 Epoch 38, Batch 1400/3125: Loss 0.0366
# 🟢 Epoch 38, Batch 1500/3125: Loss 0.0296
# 🟢 Epoch 38, Batch 1600/3125: Loss 0.0322
# 🟢 Epoch 38, Batch 1700/3125: Loss 0.0293
# 🟢 Epoch 38, Batch 1800/3125: Loss 0.0247
# 🟢 Epoch 38, Batch 1900/3125: Loss 0.0295
# 🟢 Epoch 38, Batch 2000/3125: Loss 0.0311
# 🟢 Epoch 38, Batch 2100/3125: Loss 0.0367
# 🟢 Epoch 38, Batch 2200/3125: Loss 0.0422
# 🟢 Epoch 38, Batch 2300/3125: Loss 0.0228
# 🟢 Epoch 38, Batch 2400/3125: Loss 0.0353
# 🟢 Epoch 38, Batch 2500/3125: Loss 0.0349
# 🟢 Epoch 38, Batch 2600/3125: Loss 0.0270
# 🟢 Epoch 38, Batch 2700/3125: Loss 0.0305
# 🟢 Epoch 38, Batch 2800/3125: Loss 0.0259
# 🟢 Epoch 38, Batch 2900/3125: Loss 0.0322
# 🟢 Epoch 38, Batch 3000/3125: Loss 0.0428
# 🟢 Epoch 38, Batch 3100/3125: Loss 0.0258
# ✅ Epoch 38 Done: Loss 93.0841, Train Acc: 0.3941, Time: 221.90s
# 📉 Learning Rate after Epoch 38: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 39, Batch 0/3125: Loss 0.0318
# 🟢 Epoch 39, Batch 100/3125: Loss 0.0335
# 🟢 Epoch 39, Batch 200/3125: Loss 0.0352
# 🟢 Epoch 39, Batch 300/3125: Loss 0.0240
# 🟢 Epoch 39, Batch 400/3125: Loss 0.0443
# 🟢 Epoch 39, Batch 500/3125: Loss 0.0265
# 🟢 Epoch 39, Batch 600/3125: Loss 0.0198
# 🟢 Epoch 39, Batch 700/3125: Loss 0.0280
# 🟢 Epoch 39, Batch 800/3125: Loss 0.0374
# 🟢 Epoch 39, Batch 900/3125: Loss 0.0311
# 🟢 Epoch 39, Batch 1000/3125: Loss 0.0308
# 🟢 Epoch 39, Batch 1100/3125: Loss 0.0323
# 🟢 Epoch 39, Batch 1200/3125: Loss 0.0311
# 🟢 Epoch 39, Batch 1300/3125: Loss 0.0354
# 🟢 Epoch 39, Batch 1400/3125: Loss 0.0341
# 🟢 Epoch 39, Batch 1500/3125: Loss 0.0295
# 🟢 Epoch 39, Batch 1600/3125: Loss 0.0191
# 🟢 Epoch 39, Batch 1700/3125: Loss 0.0350
# 🟢 Epoch 39, Batch 1800/3125: Loss 0.0275
# 🟢 Epoch 39, Batch 1900/3125: Loss 0.0257
# 🟢 Epoch 39, Batch 2000/3125: Loss 0.0301
# 🟢 Epoch 39, Batch 2100/3125: Loss 0.0278
# 🟢 Epoch 39, Batch 2200/3125: Loss 0.0289
# 🟢 Epoch 39, Batch 2300/3125: Loss 0.0321
# 🟢 Epoch 39, Batch 2400/3125: Loss 0.0340
# 🟢 Epoch 39, Batch 2500/3125: Loss 0.0296
# 🟢 Epoch 39, Batch 2600/3125: Loss 0.0194
# 🟢 Epoch 39, Batch 2700/3125: Loss 0.0286
# 🟢 Epoch 39, Batch 2800/3125: Loss 0.0350
# 🟢 Epoch 39, Batch 2900/3125: Loss 0.0281
# 🟢 Epoch 39, Batch 3000/3125: Loss 0.0321
# 🟢 Epoch 39, Batch 3100/3125: Loss 0.0318
# ✅ Epoch 39 Done: Loss 93.4418, Train Acc: 0.3932, Time: 221.91s
# 📉 Learning Rate after Epoch 39: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 40, Batch 0/3125: Loss 0.0326
# 🟢 Epoch 40, Batch 100/3125: Loss 0.0358
# 🟢 Epoch 40, Batch 200/3125: Loss 0.0228
# 🟢 Epoch 40, Batch 300/3125: Loss 0.0257
# 🟢 Epoch 40, Batch 400/3125: Loss 0.0259
# 🟢 Epoch 40, Batch 500/3125: Loss 0.0332
# 🟢 Epoch 40, Batch 600/3125: Loss 0.0235
# 🟢 Epoch 40, Batch 700/3125: Loss 0.0272
# 🟢 Epoch 40, Batch 800/3125: Loss 0.0259
# 🟢 Epoch 40, Batch 900/3125: Loss 0.0306
# 🟢 Epoch 40, Batch 1000/3125: Loss 0.0346
# 🟢 Epoch 40, Batch 1100/3125: Loss 0.0362
# 🟢 Epoch 40, Batch 1200/3125: Loss 0.0356
# 🟢 Epoch 40, Batch 1300/3125: Loss 0.0266
# 🟢 Epoch 40, Batch 1400/3125: Loss 0.0379
# 🟢 Epoch 40, Batch 1500/3125: Loss 0.0313
# 🟢 Epoch 40, Batch 1600/3125: Loss 0.0350
# 🟢 Epoch 40, Batch 1700/3125: Loss 0.0334
# 🟢 Epoch 40, Batch 1800/3125: Loss 0.0329
# 🟢 Epoch 40, Batch 1900/3125: Loss 0.0221
# 🟢 Epoch 40, Batch 2000/3125: Loss 0.0318
# 🟢 Epoch 40, Batch 2100/3125: Loss 0.0201
# 🟢 Epoch 40, Batch 2200/3125: Loss 0.0261
# 🟢 Epoch 40, Batch 2300/3125: Loss 0.0356
# 🟢 Epoch 40, Batch 2400/3125: Loss 0.0386
# 🟢 Epoch 40, Batch 2500/3125: Loss 0.0291
# 🟢 Epoch 40, Batch 2600/3125: Loss 0.0311
# 🟢 Epoch 40, Batch 2700/3125: Loss 0.0250
# 🟢 Epoch 40, Batch 2800/3125: Loss 0.0237
# 🟢 Epoch 40, Batch 2900/3125: Loss 0.0349
# 🟢 Epoch 40, Batch 3000/3125: Loss 0.0256
# 🟢 Epoch 40, Batch 3100/3125: Loss 0.0341
# ✅ Epoch 40 Done: Loss 93.9898, Train Acc: 0.3923, Time: 221.34s
# 📉 Learning Rate after Epoch 40: 0.000500
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 41, Batch 0/3125: Loss 0.0327
# 🟢 Epoch 41, Batch 100/3125: Loss 0.0310
# 🟢 Epoch 41, Batch 200/3125: Loss 0.0310
# 🟢 Epoch 41, Batch 300/3125: Loss 0.0325
# 🟢 Epoch 41, Batch 400/3125: Loss 0.0328
# 🟢 Epoch 41, Batch 500/3125: Loss 0.0279
# 🟢 Epoch 41, Batch 600/3125: Loss 0.0232
# 🟢 Epoch 41, Batch 700/3125: Loss 0.0326
# 🟢 Epoch 41, Batch 800/3125: Loss 0.0313
# 🟢 Epoch 41, Batch 900/3125: Loss 0.0396
# 🟢 Epoch 41, Batch 1000/3125: Loss 0.0285
# 🟢 Epoch 41, Batch 1100/3125: Loss 0.0290
# 🟢 Epoch 41, Batch 1200/3125: Loss 0.0293
# 🟢 Epoch 41, Batch 1300/3125: Loss 0.0366
# 🟢 Epoch 41, Batch 1400/3125: Loss 0.0242
# 🟢 Epoch 41, Batch 1500/3125: Loss 0.0326
# 🟢 Epoch 41, Batch 1600/3125: Loss 0.0238
# 🟢 Epoch 41, Batch 1700/3125: Loss 0.0270
# 🟢 Epoch 41, Batch 1800/3125: Loss 0.0283
# 🟢 Epoch 41, Batch 1900/3125: Loss 0.0406
# 🟢 Epoch 41, Batch 2000/3125: Loss 0.0321
# 🟢 Epoch 41, Batch 2100/3125: Loss 0.0304
# 🟢 Epoch 41, Batch 2200/3125: Loss 0.0262
# 🟢 Epoch 41, Batch 2300/3125: Loss 0.0387
# 🟢 Epoch 41, Batch 2400/3125: Loss 0.0236
# 🟢 Epoch 41, Batch 2500/3125: Loss 0.0373
# 🟢 Epoch 41, Batch 2600/3125: Loss 0.0332
# 🟢 Epoch 41, Batch 2700/3125: Loss 0.0346
# 🟢 Epoch 41, Batch 2800/3125: Loss 0.0473
# 🟢 Epoch 41, Batch 2900/3125: Loss 0.0463
# 🟢 Epoch 41, Batch 3000/3125: Loss 0.0268
# 🟢 Epoch 41, Batch 3100/3125: Loss 0.0290
# ✅ Epoch 41 Done: Loss 93.5765, Train Acc: 0.3936, Time: 223.52s
# 📉 Learning Rate after Epoch 41: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 42, Batch 0/3125: Loss 0.0275
# 🟢 Epoch 42, Batch 100/3125: Loss 0.0271
# 🟢 Epoch 42, Batch 200/3125: Loss 0.0230
# 🟢 Epoch 42, Batch 300/3125: Loss 0.0268
# 🟢 Epoch 42, Batch 400/3125: Loss 0.0388
# 🟢 Epoch 42, Batch 500/3125: Loss 0.0324
# 🟢 Epoch 42, Batch 600/3125: Loss 0.0270
# 🟢 Epoch 42, Batch 700/3125: Loss 0.0410
# 🟢 Epoch 42, Batch 800/3125: Loss 0.0307
# 🟢 Epoch 42, Batch 900/3125: Loss 0.0253
# 🟢 Epoch 42, Batch 1000/3125: Loss 0.0260
# 🟢 Epoch 42, Batch 1100/3125: Loss 0.0331
# 🟢 Epoch 42, Batch 1200/3125: Loss 0.0290
# 🟢 Epoch 42, Batch 1300/3125: Loss 0.0282
# 🟢 Epoch 42, Batch 1400/3125: Loss 0.0302
# 🟢 Epoch 42, Batch 1500/3125: Loss 0.0252
# 🟢 Epoch 42, Batch 1600/3125: Loss 0.0292
# 🟢 Epoch 42, Batch 1700/3125: Loss 0.0291
# 🟢 Epoch 42, Batch 1800/3125: Loss 0.0281
# 🟢 Epoch 42, Batch 1900/3125: Loss 0.0370
# 🟢 Epoch 42, Batch 2000/3125: Loss 0.0352
# 🟢 Epoch 42, Batch 2100/3125: Loss 0.0324
# 🟢 Epoch 42, Batch 2200/3125: Loss 0.0337
# 🟢 Epoch 42, Batch 2300/3125: Loss 0.0331
# 🟢 Epoch 42, Batch 2400/3125: Loss 0.0321
# 🟢 Epoch 42, Batch 2500/3125: Loss 0.0307
# 🟢 Epoch 42, Batch 2600/3125: Loss 0.0238
# 🟢 Epoch 42, Batch 2700/3125: Loss 0.0340
# 🟢 Epoch 42, Batch 2800/3125: Loss 0.0351
# 🟢 Epoch 42, Batch 2900/3125: Loss 0.0320
# 🟢 Epoch 42, Batch 3000/3125: Loss 0.0246
# 🟢 Epoch 42, Batch 3100/3125: Loss 0.0364
# ✅ Epoch 42 Done: Loss 93.1562, Train Acc: 0.3976, Time: 223.39s
# 📉 Learning Rate after Epoch 42: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 43, Batch 0/3125: Loss 0.0331
# 🟢 Epoch 43, Batch 100/3125: Loss 0.0218
# 🟢 Epoch 43, Batch 200/3125: Loss 0.0283
# 🟢 Epoch 43, Batch 300/3125: Loss 0.0259
# 🟢 Epoch 43, Batch 400/3125: Loss 0.0343
# 🟢 Epoch 43, Batch 500/3125: Loss 0.0263
# 🟢 Epoch 43, Batch 600/3125: Loss 0.0279
# 🟢 Epoch 43, Batch 700/3125: Loss 0.0285
# 🟢 Epoch 43, Batch 800/3125: Loss 0.0378
# 🟢 Epoch 43, Batch 900/3125: Loss 0.0395
# 🟢 Epoch 43, Batch 1000/3125: Loss 0.0377
# 🟢 Epoch 43, Batch 1100/3125: Loss 0.0258
# 🟢 Epoch 43, Batch 1200/3125: Loss 0.0374
# 🟢 Epoch 43, Batch 1300/3125: Loss 0.0375
# 🟢 Epoch 43, Batch 1400/3125: Loss 0.0253
# 🟢 Epoch 43, Batch 1500/3125: Loss 0.0379
# 🟢 Epoch 43, Batch 1600/3125: Loss 0.0275
# 🟢 Epoch 43, Batch 1700/3125: Loss 0.0293
# 🟢 Epoch 43, Batch 1800/3125: Loss 0.0384
# 🟢 Epoch 43, Batch 1900/3125: Loss 0.0307
# 🟢 Epoch 43, Batch 2000/3125: Loss 0.0251
# 🟢 Epoch 43, Batch 2100/3125: Loss 0.0345
# 🟢 Epoch 43, Batch 2200/3125: Loss 0.0259
# 🟢 Epoch 43, Batch 2300/3125: Loss 0.0210
# 🟢 Epoch 43, Batch 2400/3125: Loss 0.0374
# 🟢 Epoch 43, Batch 2500/3125: Loss 0.0243
# 🟢 Epoch 43, Batch 2600/3125: Loss 0.0290
# 🟢 Epoch 43, Batch 2700/3125: Loss 0.0283
# 🟢 Epoch 43, Batch 2800/3125: Loss 0.0266
# 🟢 Epoch 43, Batch 2900/3125: Loss 0.0313
# 🟢 Epoch 43, Batch 3000/3125: Loss 0.0288
# 🟢 Epoch 43, Batch 3100/3125: Loss 0.0318
# ✅ Epoch 43 Done: Loss 91.7160, Train Acc: 0.3995, Time: 223.35s
# 📉 Learning Rate after Epoch 43: 0.000397
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 44, Batch 0/3125: Loss 0.0347
# 🟢 Epoch 44, Batch 100/3125: Loss 0.0330
# 🟢 Epoch 44, Batch 200/3125: Loss 0.0310
# 🟢 Epoch 44, Batch 300/3125: Loss 0.0287
# 🟢 Epoch 44, Batch 400/3125: Loss 0.0198
# 🟢 Epoch 44, Batch 500/3125: Loss 0.0232
# 🟢 Epoch 44, Batch 600/3125: Loss 0.0294
# 🟢 Epoch 44, Batch 700/3125: Loss 0.0267
# 🟢 Epoch 44, Batch 800/3125: Loss 0.0282
# 🟢 Epoch 44, Batch 900/3125: Loss 0.0320
# 🟢 Epoch 44, Batch 1000/3125: Loss 0.0320
# 🟢 Epoch 44, Batch 1100/3125: Loss 0.0261
# 🟢 Epoch 44, Batch 1200/3125: Loss 0.0359
# 🟢 Epoch 44, Batch 1300/3125: Loss 0.0314
# 🟢 Epoch 44, Batch 1400/3125: Loss 0.0325
# 🟢 Epoch 44, Batch 1500/3125: Loss 0.0241
# 🟢 Epoch 44, Batch 1600/3125: Loss 0.0238
# 🟢 Epoch 44, Batch 1700/3125: Loss 0.0263
# 🟢 Epoch 44, Batch 1800/3125: Loss 0.0340
# 🟢 Epoch 44, Batch 1900/3125: Loss 0.0246
# 🟢 Epoch 44, Batch 2000/3125: Loss 0.0248
# 🟢 Epoch 44, Batch 2100/3125: Loss 0.0284
# 🟢 Epoch 44, Batch 2200/3125: Loss 0.0327
# 🟢 Epoch 44, Batch 2300/3125: Loss 0.0325
# 🟢 Epoch 44, Batch 2400/3125: Loss 0.0234
# 🟢 Epoch 44, Batch 2500/3125: Loss 0.0260
# 🟢 Epoch 44, Batch 2600/3125: Loss 0.0220
# 🟢 Epoch 44, Batch 2700/3125: Loss 0.0266
# 🟢 Epoch 44, Batch 2800/3125: Loss 0.0366
# 🟢 Epoch 44, Batch 2900/3125: Loss 0.0225
# 🟢 Epoch 44, Batch 3000/3125: Loss 0.0235
# 🟢 Epoch 44, Batch 3100/3125: Loss 0.0232
# ✅ Epoch 44 Done: Loss 90.7225, Train Acc: 0.4023, Time: 222.31s
# 📉 Learning Rate after Epoch 44: 0.000327
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 45, Batch 0/3125: Loss 0.0223
# 🟢 Epoch 45, Batch 100/3125: Loss 0.0268
# 🟢 Epoch 45, Batch 200/3125: Loss 0.0459
# 🟢 Epoch 45, Batch 300/3125: Loss 0.0218
# 🟢 Epoch 45, Batch 400/3125: Loss 0.0339
# 🟢 Epoch 45, Batch 500/3125: Loss 0.0301
# 🟢 Epoch 45, Batch 600/3125: Loss 0.0314
# 🟢 Epoch 45, Batch 700/3125: Loss 0.0242
# 🟢 Epoch 45, Batch 800/3125: Loss 0.0258
# 🟢 Epoch 45, Batch 900/3125: Loss 0.0255
# 🟢 Epoch 45, Batch 1000/3125: Loss 0.0219
# 🟢 Epoch 45, Batch 1100/3125: Loss 0.0336
# 🟢 Epoch 45, Batch 1200/3125: Loss 0.0217
# 🟢 Epoch 45, Batch 1300/3125: Loss 0.0264
# 🟢 Epoch 45, Batch 1400/3125: Loss 0.0243
# 🟢 Epoch 45, Batch 1500/3125: Loss 0.0169
# 🟢 Epoch 45, Batch 1600/3125: Loss 0.0258
# 🟢 Epoch 45, Batch 1700/3125: Loss 0.0302
# 🟢 Epoch 45, Batch 1800/3125: Loss 0.0218
# 🟢 Epoch 45, Batch 1900/3125: Loss 0.0293
# 🟢 Epoch 45, Batch 2000/3125: Loss 0.0301
# 🟢 Epoch 45, Batch 2100/3125: Loss 0.0295
# 🟢 Epoch 45, Batch 2200/3125: Loss 0.0225
# 🟢 Epoch 45, Batch 2300/3125: Loss 0.0284
# 🟢 Epoch 45, Batch 2400/3125: Loss 0.0242
# 🟢 Epoch 45, Batch 2500/3125: Loss 0.0274
# 🟢 Epoch 45, Batch 2600/3125: Loss 0.0252
# 🟢 Epoch 45, Batch 2700/3125: Loss 0.0365
# 🟢 Epoch 45, Batch 2800/3125: Loss 0.0303
# 🟢 Epoch 45, Batch 2900/3125: Loss 0.0273
# 🟢 Epoch 45, Batch 3000/3125: Loss 0.0227
# 🟢 Epoch 45, Batch 3100/3125: Loss 0.0213
# ✅ Epoch 45 Done: Loss 89.2875, Train Acc: 0.4087, Time: 221.91s
# 📉 Learning Rate after Epoch 45: 0.000250
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 46, Batch 0/3125: Loss 0.0272
# 🟢 Epoch 46, Batch 100/3125: Loss 0.0284
# 🟢 Epoch 46, Batch 200/3125: Loss 0.0243
# 🟢 Epoch 46, Batch 300/3125: Loss 0.0319
# 🟢 Epoch 46, Batch 400/3125: Loss 0.0270
# 🟢 Epoch 46, Batch 500/3125: Loss 0.0277
# 🟢 Epoch 46, Batch 600/3125: Loss 0.0258
# 🟢 Epoch 46, Batch 700/3125: Loss 0.0353
# 🟢 Epoch 46, Batch 800/3125: Loss 0.0253
# 🟢 Epoch 46, Batch 900/3125: Loss 0.0297
# 🟢 Epoch 46, Batch 1000/3125: Loss 0.0280
# 🟢 Epoch 46, Batch 1100/3125: Loss 0.0260
# 🟢 Epoch 46, Batch 1200/3125: Loss 0.0336
# 🟢 Epoch 46, Batch 1300/3125: Loss 0.0329
# 🟢 Epoch 46, Batch 1400/3125: Loss 0.0283
# 🟢 Epoch 46, Batch 1500/3125: Loss 0.0265
# 🟢 Epoch 46, Batch 1600/3125: Loss 0.0278
# 🟢 Epoch 46, Batch 1700/3125: Loss 0.0250
# 🟢 Epoch 46, Batch 1800/3125: Loss 0.0348
# 🟢 Epoch 46, Batch 1900/3125: Loss 0.0286
# 🟢 Epoch 46, Batch 2000/3125: Loss 0.0248
# 🟢 Epoch 46, Batch 2100/3125: Loss 0.0285
# 🟢 Epoch 46, Batch 2200/3125: Loss 0.0300
# 🟢 Epoch 46, Batch 2300/3125: Loss 0.0189
# 🟢 Epoch 46, Batch 2400/3125: Loss 0.0277
# 🟢 Epoch 46, Batch 2500/3125: Loss 0.0242
# 🟢 Epoch 46, Batch 2600/3125: Loss 0.0297
# 🟢 Epoch 46, Batch 2700/3125: Loss 0.0195
# 🟢 Epoch 46, Batch 2800/3125: Loss 0.0215
# 🟢 Epoch 46, Batch 2900/3125: Loss 0.0261
# 🟢 Epoch 46, Batch 3000/3125: Loss 0.0325
# 🟢 Epoch 46, Batch 3100/3125: Loss 0.0287
# ✅ Epoch 46 Done: Loss 87.2266, Train Acc: 0.4163, Time: 222.21s
# 📉 Learning Rate after Epoch 46: 0.000173
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 47, Batch 0/3125: Loss 0.0294
# 🟢 Epoch 47, Batch 100/3125: Loss 0.0273
# 🟢 Epoch 47, Batch 200/3125: Loss 0.0313
# 🟢 Epoch 47, Batch 300/3125: Loss 0.0255
# 🟢 Epoch 47, Batch 400/3125: Loss 0.0262
# 🟢 Epoch 47, Batch 500/3125: Loss 0.0227
# 🟢 Epoch 47, Batch 600/3125: Loss 0.0257
# 🟢 Epoch 47, Batch 700/3125: Loss 0.0287
# 🟢 Epoch 47, Batch 800/3125: Loss 0.0177
# 🟢 Epoch 47, Batch 900/3125: Loss 0.0302
# 🟢 Epoch 47, Batch 1000/3125: Loss 0.0279
# 🟢 Epoch 47, Batch 1100/3125: Loss 0.0327
# 🟢 Epoch 47, Batch 1200/3125: Loss 0.0368
# 🟢 Epoch 47, Batch 1300/3125: Loss 0.0255
# 🟢 Epoch 47, Batch 1400/3125: Loss 0.0246
# 🟢 Epoch 47, Batch 1500/3125: Loss 0.0241
# 🟢 Epoch 47, Batch 1600/3125: Loss 0.0310
# 🟢 Epoch 47, Batch 1700/3125: Loss 0.0268
# 🟢 Epoch 47, Batch 1800/3125: Loss 0.0288
# 🟢 Epoch 47, Batch 1900/3125: Loss 0.0306
# 🟢 Epoch 47, Batch 2000/3125: Loss 0.0317
# 🟢 Epoch 47, Batch 2100/3125: Loss 0.0277
# 🟢 Epoch 47, Batch 2200/3125: Loss 0.0275
# 🟢 Epoch 47, Batch 2300/3125: Loss 0.0215
# 🟢 Epoch 47, Batch 2400/3125: Loss 0.0249
# 🟢 Epoch 47, Batch 2500/3125: Loss 0.0189
# 🟢 Epoch 47, Batch 2600/3125: Loss 0.0344
# 🟢 Epoch 47, Batch 2700/3125: Loss 0.0298
# 🟢 Epoch 47, Batch 2800/3125: Loss 0.0218
# 🟢 Epoch 47, Batch 2900/3125: Loss 0.0330
# 🟢 Epoch 47, Batch 3000/3125: Loss 0.0238
# 🟢 Epoch 47, Batch 3100/3125: Loss 0.0346
# ✅ Epoch 47 Done: Loss 85.9780, Train Acc: 0.4210, Time: 221.95s
# 📉 Learning Rate after Epoch 47: 0.000103
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 48, Batch 0/3125: Loss 0.0210
# 🟢 Epoch 48, Batch 100/3125: Loss 0.0279
# 🟢 Epoch 48, Batch 200/3125: Loss 0.0277
# 🟢 Epoch 48, Batch 300/3125: Loss 0.0163
# 🟢 Epoch 48, Batch 400/3125: Loss 0.0266
# 🟢 Epoch 48, Batch 500/3125: Loss 0.0228
# 🟢 Epoch 48, Batch 600/3125: Loss 0.0333
# 🟢 Epoch 48, Batch 700/3125: Loss 0.0336
# 🟢 Epoch 48, Batch 800/3125: Loss 0.0263
# 🟢 Epoch 48, Batch 900/3125: Loss 0.0325
# 🟢 Epoch 48, Batch 1000/3125: Loss 0.0283
# 🟢 Epoch 48, Batch 1100/3125: Loss 0.0364
# 🟢 Epoch 48, Batch 1200/3125: Loss 0.0283
# 🟢 Epoch 48, Batch 1300/3125: Loss 0.0259
# 🟢 Epoch 48, Batch 1400/3125: Loss 0.0343
# 🟢 Epoch 48, Batch 1500/3125: Loss 0.0284
# 🟢 Epoch 48, Batch 1600/3125: Loss 0.0278
# 🟢 Epoch 48, Batch 1700/3125: Loss 0.0199
# 🟢 Epoch 48, Batch 1800/3125: Loss 0.0357
# 🟢 Epoch 48, Batch 1900/3125: Loss 0.0293
# 🟢 Epoch 48, Batch 2000/3125: Loss 0.0295
# 🟢 Epoch 48, Batch 2100/3125: Loss 0.0237
# 🟢 Epoch 48, Batch 2200/3125: Loss 0.0188
# 🟢 Epoch 48, Batch 2300/3125: Loss 0.0362
# 🟢 Epoch 48, Batch 2400/3125: Loss 0.0242
# 🟢 Epoch 48, Batch 2500/3125: Loss 0.0352
# 🟢 Epoch 48, Batch 2600/3125: Loss 0.0256
# 🟢 Epoch 48, Batch 2700/3125: Loss 0.0365
# 🟢 Epoch 48, Batch 2800/3125: Loss 0.0219
# 🟢 Epoch 48, Batch 2900/3125: Loss 0.0279
# 🟢 Epoch 48, Batch 3000/3125: Loss 0.0267
# 🟢 Epoch 48, Batch 3100/3125: Loss 0.0365
# ✅ Epoch 48 Done: Loss 85.7524, Train Acc: 0.4222, Time: 222.25s
# 📉 Learning Rate after Epoch 48: 0.000048
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 49, Batch 0/3125: Loss 0.0291
# 🟢 Epoch 49, Batch 100/3125: Loss 0.0305
# 🟢 Epoch 49, Batch 200/3125: Loss 0.0320
# 🟢 Epoch 49, Batch 300/3125: Loss 0.0341
# 🟢 Epoch 49, Batch 400/3125: Loss 0.0289
# 🟢 Epoch 49, Batch 500/3125: Loss 0.0254
# 🟢 Epoch 49, Batch 600/3125: Loss 0.0211
# 🟢 Epoch 49, Batch 700/3125: Loss 0.0316
# 🟢 Epoch 49, Batch 800/3125: Loss 0.0212
# 🟢 Epoch 49, Batch 900/3125: Loss 0.0230
# 🟢 Epoch 49, Batch 1000/3125: Loss 0.0209

# %%
# ✅ Save trained model
model_save_path = "mask_rcnn_trained.pth"
torch.save(model.state_dict(), model_save_path)
print(f"✅ Model saved as {model_save_path}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-69bf4f732f97> in <cell line: 0>()
#       1 # ✅ Save trained model
#       2 model_save_path = "mask_rcnn_trained.pth"
# ----> 3 torch.save(model.state_dict(), model_save_path)
#       4 print(f"✅ Model saved as {model_save_path}")
#
# NameError: name 'model' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

save_path = "/content/drive/MyDrive/mask_rcnn_trained.pth"  # Change path if needed
torch.save(model.state_dict(), save_path)

print(f"✅ Model saved to Google Drive at {save_path}")
# Out:
# Mounted at /content/drive
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-53fba121096d> in <cell line: 0>()
#       3
#       4 save_path = "/content/drive/MyDrive/mask_rcnn_trained.pth"  # Change path if needed
# ----> 5 torch.save(model.state_dict(), save_path)
#       6
#       7 print(f"✅ Model saved to Google Drive at {save_path}")
#
# NameError: name 'model' is not defined

# %%
import torch

# ✅ Define the new save path
save_path = "/content/drive/MyDrive/mask_rcnn_trained_v2.pth"  # Different name

# ✅ Save the entire model (architecture + weights)
torch.save(model, save_path)

print(f"✅ Full model saved successfully at: {save_path}")
# Out:
# ---------------------------------------------------------------------------
# PicklingError                             Traceback (most recent call last)
# <ipython-input-48-f630adfdd2a8> in <cell line: 0>()
#       5
#       6 # ✅ Save the entire model (architecture + weights)
# ----> 7 torch.save(model, save_path)
#       8
#       9 print(f"✅ Full model saved successfully at: {save_path}")
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in save(obj, f, pickle_module, pickle_protocol, _use_new_zipfile_serialization, _disable_byteorder_record)
#     942     if _use_new_zipfile_serialization:
#     943         with _open_zipfile_writer(f) as opened_zipfile:
# --> 944             _save(
#     945                 obj,
#     946                 opened_zipfile,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _save(obj, zip_file, pickle_module, pickle_protocol, _disable_byteorder_record)
#    1188
#    1189     pickler = PyTorchPickler(data_buf, protocol=pickle_protocol)
# -> 1190     pickler.dump(obj)
#    1191     data_value = data_buf.getvalue()
#    1192     zip_file.write_record("data.pkl", data_value, len(data_value))
#
# PicklingError: Can't pickle <class '__main__.RPN'>: it's not the same object as __main__.RPN

# %%
# Out:
# <ipython-input-32-c4722ad4e5f5>:34: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = GradScaler()
# <ipython-input-32-c4722ad4e5f5>:84: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with autocast():
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 1, Batch 0/3125: Loss 0.3478
# 🟢 Epoch 1, Batch 100/3125: Loss 0.2745
# ⚠️ Skipping batch 144 due to unstable loss
# ⚠️ Skipping batch 171 due to unstable loss
# 🟢 Epoch 1, Batch 200/3125: Loss 0.2453
# ⚠️ Skipping batch 217 due to unstable loss
# ⚠️ Skipping batch 247 due to unstable loss
# ⚠️ Skipping batch 252 due to unstable loss
# ⚠️ Skipping batch 288 due to unstable loss
# 🟢 Epoch 1, Batch 300/3125: Loss 0.2288
# ⚠️ Skipping batch 319 due to unstable loss
# ⚠️ Skipping batch 364 due to unstable loss
# ⚠️ Skipping batch 375 due to unstable loss
# 🟢 Epoch 1, Batch 400/3125: Loss 0.2303
# 🟢 Epoch 1, Batch 500/3125: Loss 0.2507
# ⚠️ Skipping batch 597 due to unstable loss
# 🟢 Epoch 1, Batch 600/3125: Loss 0.2138
# ⚠️ Skipping batch 672 due to unstable loss
# 🟢 Epoch 1, Batch 700/3125: Loss 0.2145
# ⚠️ Skipping batch 723 due to unstable loss
# ⚠️ Skipping batch 760 due to unstable loss
# 🟢 Epoch 1, Batch 800/3125: Loss 0.2520
# ⚠️ Skipping batch 821 due to unstable loss
# ⚠️ Skipping batch 838 due to unstable loss
# ⚠️ Skipping batch 877 due to unstable loss
# ⚠️ Skipping batch 885 due to unstable loss
# 🟢 Epoch 1, Batch 900/3125: Loss 0.2243
# ⚠️ Skipping batch 983 due to unstable loss
# ⚠️ Skipping batch 991 due to unstable loss
# ⚠️ Skipping batch 995 due to unstable loss
# 🟢 Epoch 1, Batch 1000/3125: Loss 0.2472
# ⚠️ Skipping batch 1033 due to unstable loss
# ⚠️ Skipping batch 1050 due to unstable loss
# ⚠️ Skipping batch 1069 due to unstable loss
# 🟢 Epoch 1, Batch 1100/3125: Loss 0.2174
# ⚠️ Skipping batch 1141 due to unstable loss
# ⚠️ Skipping batch 1173 due to unstable loss
# ⚠️ Skipping batch 1192 due to unstable loss
# ⚠️ Skipping batch 1197 due to unstable loss
# 🟢 Epoch 1, Batch 1200/3125: Loss 0.2368
# ⚠️ Skipping batch 1269 due to unstable loss
# 🟢 Epoch 1, Batch 1300/3125: Loss 0.1990
# ⚠️ Skipping batch 1320 due to unstable loss
# ⚠️ Skipping batch 1321 due to unstable loss
# ⚠️ Skipping batch 1362 due to unstable loss
# ⚠️ Skipping batch 1366 due to unstable loss
# ⚠️ Skipping batch 1388 due to unstable loss
# ⚠️ Skipping batch 1396 due to unstable loss
# 🟢 Epoch 1, Batch 1400/3125: Loss 0.2220
# ⚠️ Skipping batch 1405 due to unstable loss
# ⚠️ Skipping batch 1407 due to unstable loss
# ⚠️ Skipping batch 1490 due to unstable loss
# 🟢 Epoch 1, Batch 1500/3125: Loss 0.2500
# ⚠️ Skipping batch 1513 due to unstable loss
# ⚠️ Skipping batch 1520 due to unstable loss
# ⚠️ Skipping batch 1530 due to unstable loss
# ⚠️ Skipping batch 1540 due to unstable loss
# 🟢 Epoch 1, Batch 1600/3125: Loss 0.2296
# ⚠️ Skipping batch 1647 due to unstable loss
# ⚠️ Skipping batch 1661 due to unstable loss
# 🟢 Epoch 1, Batch 1700/3125: Loss 0.2152
# ⚠️ Skipping batch 1725 due to unstable loss
# ⚠️ Skipping batch 1749 due to unstable loss
# ⚠️ Skipping batch 1754 due to unstable loss
# ⚠️ Skipping batch 1793 due to unstable loss
# 🟢 Epoch 1, Batch 1800/3125: Loss 0.2090
# ⚠️ Skipping batch 1804 due to unstable loss
# ⚠️ Skipping batch 1885 due to unstable loss
# ⚠️ Skipping batch 1886 due to unstable loss
# ⚠️ Skipping batch 1890 due to unstable loss
# 🟢 Epoch 1, Batch 1900/3125: Loss 0.2240
# 🟢 Epoch 1, Batch 2000/3125: Loss 0.2565
# ⚠️ Skipping batch 2023 due to unstable loss
# ⚠️ Skipping batch 2043 due to unstable loss
# 🟢 Epoch 1, Batch 2100/3125: Loss 0.2527
# ⚠️ Skipping batch 2130 due to unstable loss
# 🟢 Epoch 1, Batch 2200/3125: Loss 0.2556
# ⚠️ Skipping batch 2262 due to unstable loss
# 🟢 Epoch 1, Batch 2300/3125: Loss 0.2204
# ⚠️ Skipping batch 2313 due to unstable loss
# ⚠️ Skipping batch 2350 due to unstable loss
# ⚠️ Skipping batch 2364 due to unstable loss
# ⚠️ Skipping batch 2365 due to unstable loss
# ⚠️ Skipping batch 2386 due to unstable loss
# ⚠️ Skipping batch 2388 due to unstable loss
# ⚠️ Skipping batch 2398 due to unstable loss
# 🟢 Epoch 1, Batch 2400/3125: Loss 0.1943
# ⚠️ Skipping batch 2460 due to unstable loss
# 🟢 Epoch 1, Batch 2500/3125: Loss 0.2112
# ⚠️ Skipping batch 2516 due to unstable loss
# ⚠️ Skipping batch 2523 due to unstable loss
# 🟢 Epoch 1, Batch 2600/3125: Loss 0.2228
# ⚠️ Skipping batch 2603 due to unstable loss
# ⚠️ Skipping batch 2623 due to unstable loss
# ⚠️ Skipping batch 2624 due to unstable loss
# ⚠️ Skipping batch 2632 due to unstable loss
# ⚠️ Skipping batch 2639 due to unstable loss
# ⚠️ Skipping batch 2643 due to unstable loss
# ⚠️ Skipping batch 2644 due to unstable loss
# ⚠️ Skipping batch 2683 due to unstable loss
# ⚠️ Skipping batch 2689 due to unstable loss
# 🟢 Epoch 1, Batch 2700/3125: Loss 0.2341
# ⚠️ Skipping batch 2713 due to unstable loss
# ⚠️ Skipping batch 2772 due to unstable loss
# ⚠️ Skipping batch 2785 due to unstable loss
# ⚠️ Skipping batch 2789 due to unstable loss
# 🟢 Epoch 1, Batch 2800/3125: Loss 0.2407
# ⚠️ Skipping batch 2814 due to unstable loss
# ⚠️ Skipping batch 2821 due to unstable loss
# ⚠️ Skipping batch 2839 due to unstable loss
# 🟢 Epoch 1, Batch 2900/3125: Loss 0.2442
# ⚠️ Skipping batch 2963 due to unstable loss
# ⚠️ Skipping batch 2991 due to unstable loss
# ⚠️ Skipping batch 2996 due to unstable loss
# 🟢 Epoch 1, Batch 3000/3125: Loss 0.2528
# ⚠️ Skipping batch 3008 due to unstable loss
# ⚠️ Skipping batch 3010 due to unstable loss
# ⚠️ Skipping batch 3032 due to unstable loss
# ⚠️ Skipping batch 3077 due to unstable loss
# ⚠️ Skipping batch 3081 due to unstable loss
# ⚠️ Skipping batch 3095 due to unstable loss
# 🟢 Epoch 1, Batch 3100/3125: Loss 0.2013
# ✅ Epoch 1 Done: Loss 729.7408, Train Acc: 0.3028, Time: 219.07s
# 📉 Learning Rate after Epoch 1: 0.000488
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 2, Batch 0/3125: Loss 0.2395
# ⚠️ Skipping batch 27 due to unstable loss
# ⚠️ Skipping batch 49 due to unstable loss
# ⚠️ Skipping batch 57 due to unstable loss
# ⚠️ Skipping batch 61 due to unstable loss
# ⚠️ Skipping batch 64 due to unstable loss
# ⚠️ Skipping batch 86 due to unstable loss
# ⚠️ Skipping batch 89 due to unstable loss
# 🟢 Epoch 2, Batch 100/3125: Loss 0.2401
# ⚠️ Skipping batch 111 due to unstable loss
# ⚠️ Skipping batch 123 due to unstable loss
# ⚠️ Skipping batch 175 due to unstable loss
# ⚠️ Skipping batch 188 due to unstable loss
# ⚠️ Skipping batch 189 due to unstable loss
# ⚠️ Skipping batch 197 due to unstable loss
# 🟢 Epoch 2, Batch 200/3125: Loss 0.2085
# ⚠️ Skipping batch 228 due to unstable loss
# ⚠️ Skipping batch 235 due to unstable loss
# ⚠️ Skipping batch 247 due to unstable loss
# ⚠️ Skipping batch 249 due to unstable loss
# ⚠️ Skipping batch 252 due to unstable loss
# ⚠️ Skipping batch 282 due to unstable loss
# ⚠️ Skipping batch 295 due to unstable loss
# ⚠️ Skipping batch 298 due to unstable loss
# 🟢 Epoch 2, Batch 300/3125: Loss 0.2301
# ⚠️ Skipping batch 344 due to unstable loss
# 🟢 Epoch 2, Batch 400/3125: Loss 0.2089
# ⚠️ Skipping batch 418 due to unstable loss
# ⚠️ Skipping batch 439 due to unstable loss
# ⚠️ Skipping batch 483 due to unstable loss
# 🟢 Epoch 2, Batch 500/3125: Loss 0.2377
# ⚠️ Skipping batch 521 due to unstable loss
# 🟢 Epoch 2, Batch 600/3125: Loss 0.2292
# ⚠️ Skipping batch 631 due to unstable loss
# ⚠️ Skipping batch 664 due to unstable loss
# 🟢 Epoch 2, Batch 700/3125: Loss 0.2154
# ⚠️ Skipping batch 1811 due to unstable loss
# ⚠️ Skipping batch 1820 due to unstable loss
# ⚠️ Skipping batch 1860 due to unstable loss
# ⚠️ Skipping batch 1894 due to unstable loss
# ⚠️ Skipping batch 1899 due to unstable loss
# 🟢 Epoch 2, Batch 1900/3125: Loss 0.2541
# ⚠️ Skipping batch 1908 due to unstable loss
# ⚠️ Skipping batch 1919 due to unstable loss
# ⚠️ Skipping batch 1949 due to unstable loss
# ⚠️ Skipping batch 1956 due to unstable loss
# ⚠️ Skipping batch 1968 due to unstable loss
# ⚠️ Skipping batch 1969 due to unstable loss
# 🟢 Epoch 2, Batch 2000/3125: Loss 0.2149
# ⚠️ Skipping batch 2016 due to unstable loss
# ⚠️ Skipping batch 2056 due to unstable loss
# ⚠️ Skipping batch 2068 due to unstable loss
# ⚠️ Skipping batch 2070 due to unstable loss
# ⚠️ Skipping batch 2083 due to unstable loss
# ⚠️ Skipping batch 2093 due to unstable loss
# 🟢 Epoch 2, Batch 2100/3125: Loss 0.2205
# ⚠️ Skipping batch 2125 due to unstable loss
# ⚠️ Skipping batch 2133 due to unstable loss
# ⚠️ Skipping batch 2135 due to unstable loss
# ⚠️ Skipping batch 2171 due to unstable loss
# ⚠️ Skipping batch 2186 due to unstable loss
# 🟢 Epoch 2, Batch 2200/3125: Loss 0.2154
# ⚠️ Skipping batch 2215 due to unstable loss
# ⚠️ Skipping batch 2244 due to unstable loss
# ⚠️ Skipping batch 2266 due to unstable loss
# ⚠️ Skipping batch 2275 due to unstable loss
# ⚠️ Skipping batch 2279 due to unstable loss
# ⚠️ Skipping batch 2289 due to unstable loss
# ⚠️ Skipping batch 2295 due to unstable loss
# ⚠️ Skipping batch 2296 due to unstable loss
# 🟢 Epoch 2, Batch 2300/3125: Loss 0.2152
# ⚠️ Skipping batch 2331 due to unstable loss
# ⚠️ Skipping batch 2375 due to unstable loss
# ⚠️ Skipping batch 2383 due to unstable loss
# ⚠️ Skipping batch 2385 due to unstable loss
# ⚠️ Skipping batch 2397 due to unstable loss
# 🟢 Epoch 2, Batch 2400/3125: Loss 0.2293
# ⚠️ Skipping batch 2415 due to unstable loss
# ⚠️ Skipping batch 2432 due to unstable loss
# ⚠️ Skipping batch 2466 due to unstable loss
# ⚠️ Skipping batch 2484 due to unstable loss
# ⚠️ Skipping batch 2488 due to unstable loss
# ⚠️ Skipping batch 2499 due to unstable loss
# 🟢 Epoch 2, Batch 2500/3125: Loss 0.2282
# ⚠️ Skipping batch 2548 due to unstable loss
# ⚠️ Skipping batch 2554 due to unstable loss
# ⚠️ Skipping batch 2562 due to unstable loss
# ⚠️ Skipping batch 2584 due to unstable loss
# ⚠️ Skipping batch 2590 due to unstable loss
# ⚠️ Skipping batch 2592 due to unstable loss
# ⚠️ Skipping batch 2599 due to unstable loss
# 🟢 Epoch 2, Batch 2600/3125: Loss 0.2025
# ⚠️ Skipping batch 2606 due to unstable loss
# ⚠️ Skipping batch 2616 due to unstable loss
# ⚠️ Skipping batch 2629 due to unstable loss
# ⚠️ Skipping batch 2653 due to unstable loss
# ⚠️ Skipping batch 2661 due to unstable loss
# 🟢 Epoch 2, Batch 2700/3125: Loss 0.2140
# ⚠️ Skipping batch 2705 due to unstable loss
# ⚠️ Skipping batch 2744 due to unstable loss
# ⚠️ Skipping batch 2754 due to unstable loss
# 🟢 Epoch 2, Batch 2800/3125: Loss 0.2078
# ⚠️ Skipping batch 2814 due to unstable loss
# ⚠️ Skipping batch 2846 due to unstable loss
# ⚠️ Skipping batch 2858 due to unstable loss
# ⚠️ Skipping batch 2879 due to unstable loss
# 🟢 Epoch 2, Batch 2900/3125: Loss 0.2206
# ⚠️ Skipping batch 2922 due to unstable loss
# ⚠️ Skipping batch 2939 due to unstable loss
# ⚠️ Skipping batch 2942 due to unstable loss
# 🟢 Epoch 2, Batch 3000/3125: Loss 0.2434
# ⚠️ Skipping batch 3003 due to unstable loss
# ⚠️ Skipping batch 3004 due to unstable loss
# ⚠️ Skipping batch 3047 due to unstable loss
# ⚠️ Skipping batch 3087 due to unstable loss
# 🟢 Epoch 2, Batch 3100/3125: Loss 0.2281
# ⚠️ Skipping batch 3124 due to unstable loss
# ✅ Epoch 2 Done: Loss 663.6840, Train Acc: 0.3115, Time: 219.23s
# 📉 Learning Rate after Epoch 2: 0.000452
# ✅ Reshaped pooled_regions: Expected 12544, Got 12544
# 🟢 Epoch 3, Batch 0/3125: Loss 0.2027
# ⚠️ Skipping batch 17 due to unstable loss
# ⚠️ Skipping batch 19 due to unstable loss
# ⚠️ Skipping batch 28 due to unstable loss
# ⚠️ Skipping batch 31 due to unstable loss
# ⚠️ Skipping batch 42 due to unstable loss
# ⚠️ Skipping batch 56 due to unstable loss
# 🟢 Epoch 3, Batch 100/3125: Loss 0.2069
# ⚠️ Skipping batch 111 due to unstable loss
# ⚠️ Skipping batch 120 due to unstable loss
# ⚠️ Skipping batch 125 due to unstable loss
# ⚠️ Skipping batch 140 due to unstable loss
# 🟢 Epoch 3, Batch 200/3125: Loss 0.2168
# ⚠️ Skipping batch 210 due to unstable loss
# ⚠️ Skipping batch 235 due to unstable loss
# ⚠️ Skipping batch 267 due to unstable loss
# ⚠️ Skipping batch 275 due to unstable loss
# ⚠️ Skipping batch 279 due to unstable loss
# ⚠️ Skipping batch 282 due to unstable loss
# 🟢 Epoch 3, Batch 300/3125: Loss 0.2059
# ⚠️ Skipping batch 303 due to unstable loss
# ⚠️ Skipping batch 326 due to unstable loss
# ⚠️ Skipping batch 333 due to unstable loss
# ⚠️ Skipping batch 385 due to unstable loss
# ⚠️ Skipping batch 389 due to unstable loss
# 🟢 Epoch 3, Batch 400/3125: Loss 0.2303
# ⚠️ Skipping batch 406 due to unstable loss
# ⚠️ Skipping batch 415 due to unstable loss
# ⚠️ Skipping batch 439 due to unstable loss
# ⚠️ Skipping batch 450 due to unstable loss
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-c4722ad4e5f5> in <cell line: 0>()
#      43     total_loss, correct_preds, total_preds = 0, 0, 0
#      44
# ---> 45     for batch_idx, (images, boxes, masks, labels) in enumerate(train_loader):
#      46         images = torch.stack([img.to(device) for img in images])
#      47         boxes = [b.to(device) for b in boxes]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1456
#    1457             assert not self._shutdown and self._tasks_outstanding > 0
# -> 1458             idx, data = self._get_data()
#    1459             self._tasks_outstanding -= 1
#    1460             if self._dataset_kind == _DatasetKind.Iterable:
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _get_data(self)
#    1418         else:
#    1419             while True:
# -> 1420                 success, data = self._try_get_data()
#    1421                 if success:
#    1422                     return data
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _try_get_data(self, timeout)
#    1249         #   (bool: whether successfully get data, any: data if successful else None)
#    1250         try:
# -> 1251             data = self._data_queue.get(timeout=timeout)
#    1252             return (True, data)
#    1253         except Exception as e:
#
# /usr/lib/python3.11/multiprocessing/queues.py in get(self, block, timeout)
#     120                 self._rlock.release()
#     121         # unserialize the data after having released the lock
# --> 122         return _ForkingPickler.loads(res)
#     123
#     124     def qsize(self):
#
# /usr/local/lib/python3.11/dist-packages/torch/multiprocessing/reductions.py in rebuild_storage_fd(cls, df, size)
#     539
#     540 def rebuild_storage_fd(cls, df, size):
# --> 541     fd = df.detach()
#     542     try:
#     543         storage = storage_from_cache(cls, fd_id(fd))
#
# /usr/lib/python3.11/multiprocessing/resource_sharer.py in detach(self)
#      56             '''Get the fd.  This should only be called once.'''
#      57             with _resource_sharer.get_connection(self._id) as conn:
# ---> 58                 return reduction.recv_handle(conn)
#      59
#      60
#
# /usr/lib/python3.11/multiprocessing/reduction.py in recv_handle(conn)
#     187         '''Receive a handle over a local connection.'''
#     188         with socket.fromfd(conn.fileno(), socket.AF_UNIX, socket.SOCK_STREAM) as s:
# --> 189             return recvfds(s, 1)[0]
#     190
#     191     def DupFd(fd):
#
# /usr/lib/python3.11/multiprocessing/reduction.py in recvfds(sock, size)
#     155         a = array.array('i')
#     156         bytes_size = a.itemsize * size
# --> 157         msg, ancdata, flags, addr = sock.recvmsg(1, socket.CMSG_SPACE(bytes_size))
#     158         if not msg and not ancdata:
#     159             raise EOFError
#
# KeyboardInterrupt:

# %%
import torch
import torchvision
from torch.utils.data import DataLoader
from torch.nn.functional import interpolate
from collections import Counter
import os

# ✅ Define Google Drive model path
model_path = "/content/drive/MyDrive/mask_rcnn_trained_approach2_full_model.pth"

# ✅ Verify that the model file exists
if os.path.exists(model_path):
    print("✅ Model file found!")
else:
    raise FileNotFoundError("❌ Model file NOT found. Check your Google Drive path.")

# ✅ Load the trained model
# ✅ Load Full Model Instead of Just State Dictionary
def load_trained_model(model_path, device):
    """Load a trained Mask R-CNN model from a .pth file"""
    checkpoint = torch.load(model_path, map_location=device)

    if isinstance(checkpoint, dict):
        # ✅ Case 1: Model was saved using state_dict() only
        model = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=False, num_classes=91)
        model.load_state_dict(checkpoint)  # Load weights
    else:
        # ✅ Case 2: Model was saved as a full model object
        model = checkpoint  # Directly assign the model

    model.to(device)
    model.eval()  # Set to evaluation mode
    print("✅ Model Loaded Successfully!")
    return model

# ✅ Dataset & DataLoader
class COCODataset(torch.utils.data.Dataset):
    def __init__(self, root, annotation_file, transform=None):
        from pycocotools.coco import COCO
        self.coco = COCO(annotation_file)
        self.root = root
        self.transform = transform
        self.image_ids = list(self.coco.imgs.keys())

    def __getitem__(self, index):
        from PIL import Image
        image_id = self.image_ids[index]
        image_info = self.coco.loadImgs(image_id)[0]
        path = os.path.join(self.root, image_info["file_name"])
        image = Image.open(path).convert("RGB")

        ann_ids = self.coco.getAnnIds(imgIds=image_id)
        anns = self.coco.loadAnns(ann_ids)

        boxes = []
        labels = []
        masks = []

        for ann in anns:
            x, y, w, h = ann["bbox"]
            boxes.append([x, y, x + w, y + h])
            labels.append(ann["category_id"])
            mask = self.coco.annToMask(ann)
            masks.append(mask)

        if self.transform:
            image = self.transform(image)

        return image, torch.tensor(boxes), torch.tensor(masks), torch.tensor(labels)

    def __len__(self):
        return len(self.image_ids)


# ✅ Data Transformation (Modify as needed)
from torchvision import transforms
transform = transforms.Compose([
    transforms.Resize((256, 256)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])


# ✅ DataLoader
def collate_fn(batch):
    images, boxes, masks, labels = zip(*batch)
    return images, boxes, masks, labels

test_dataset = COCODataset("val2017", "annotations/instances_val2017.json", transform)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=False, collate_fn=collate_fn, num_workers=4)

# ✅ COCO Labels Dictionary
COCO_CLASSES = {
    1: "person", 2: "bicycle", 3: "car", 4: "motorcycle", 5: "airplane",
    6: "bus", 7: "train", 8: "truck", 9: "boat", 10: "traffic light",
    11: "fire hydrant", 13: "stop sign", 14: "parking meter", 15: "bench",
    16: "bird", 17: "cat", 18: "dog", 19: "horse", 20: "sheep",
    21: "cow", 22: "elephant", 23: "bear", 24: "zebra", 25: "giraffe",
    27: "backpack", 28: "umbrella", 31: "handbag", 32: "tie", 33: "suitcase",
    34: "frisbee", 35: "skis", 36: "snowboard", 37: "sports ball", 38: "kite",
    39: "baseball bat", 40: "baseball glove", 41: "skateboard", 42: "surfboard",
    43: "tennis racket", 44: "bottle", 46: "wine glass", 47: "cup", 48: "fork",
    49: "knife", 50: "spoon", 51: "bowl", 52: "banana", 53: "apple",
    54: "sandwich", 55: "orange", 56: "broccoli", 57: "carrot", 58: "hot dog",
    59: "pizza", 60: "donut", 61: "cake", 62: "chair", 63: "couch",
    64: "potted plant", 65: "bed", 67: "dining table", 70: "toilet",
    72: "tv", 73: "laptop", 74: "mouse", 75: "remote", 76: "keyboard",
    77: "cell phone", 78: "microwave", 79: "oven", 80: "toaster", 81: "sink",
    82: "refrigerator", 84: "book", 85: "clock", 86: "vase", 87: "scissors",
    88: "teddy bear", 89: "hair drier", 90: "toothbrush"
}


# ✅ Evaluation Function
def evaluate_model(model, test_loader, device):
    model.eval()
    total_correct, total_samples = 0, 0

    with torch.no_grad():
        for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
            images = torch.stack([img.to(device) for img in images])
            labels = [l.to(device) for l in labels]

            if len(labels) == 0:
                print(f"⚠️ Skipping batch {batch_idx} due to empty labels")
                continue

            outputs = model(images)
            pred_labels = [output["labels"] for output in outputs]

            # Flatten & Convert Labels
            gt_labels = torch.cat(labels, dim=0) if len(labels) > 0 else torch.tensor([], device=device)
            pred_labels = torch.cat(pred_labels, dim=0) if len(pred_labels) > 0 else torch.tensor([], device=device)

            # ✅ Ensure Labels Are in COCO Range
            if len(gt_labels) > 0 and len(pred_labels) > 0:
                assert gt_labels.min() >= 1 and gt_labels.max() <= 90, "GT labels out of range!"
                assert pred_labels.min() >= 1 and pred_labels.max() <= 90, "Pred labels out of range!"

            # ✅ Match Predictions to Ground Truth
            matches = torch.isin(pred_labels, gt_labels)
            total_correct += matches.sum().item()
            total_samples += len(gt_labels)

            if batch_idx % 10 == 0:
                print("Predicted Label Distribution:", Counter(pred_labels.tolist()).most_common(5))

    accuracy = total_correct / total_samples if total_samples > 0 else 0.0
    print(f"✅ Evaluation Done: Accuracy {accuracy:.4f}")
    return accuracy


# ✅ Load Model and Run Evaluation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = load_trained_model(model_path, device)
accuracy = evaluate_model(model, test_loader, device)
# Out:
# ✅ Model file found!
# loading annotations into memory...
# Done (t=0.45s)
# creating index...
# index created!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-5276ead922fa> in <cell line: 0>()
#     153 # ✅ Load Model and Run Evaluation
#     154 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# --> 155 model = load_trained_model(model_path, device)
#     156 accuracy = evaluate_model(model, test_loader, device)
#
# <ipython-input-22-5276ead922fa> in load_trained_model(model_path, device)
#      19 def load_trained_model(model_path, device):
#      20     """Load a trained Mask R-CNN model from a .pth file"""
# ---> 21     checkpoint = torch.load(model_path, map_location=device)
#      22
#      23     if isinstance(checkpoint, dict):
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in load(f, map_location, pickle_module, weights_only, mmap, **pickle_load_args)
#    1460                 if weights_only:
#    1461                     try:
# -> 1462                         return _load(
#    1463                             opened_zipfile,
#    1464                             map_location,
#
# /usr/local/lib/python3.11/dist-packages/torch/serialization.py in _load(zip_file, map_location, pickle_module, pickle_file, overall_storage, **pickle_load_args)
#    1962     global _serialization_tls
#    1963     _serialization_tls.map_location = map_location
# -> 1964     result = unpickler.load()
#    1965     _serialization_tls.map_location = None
#    1966
#
# /usr/local/lib/python3.11/dist-packages/torch/_weights_only_unpickler.py in load(self)
#     332                 if full_path in _get_allowed_globals():
#     333                     self.append(_get_allowed_globals()[full_path])
# --> 334                 elif full_path in _get_user_allowed_globals():
#     335                     self.append(_get_user_allowed_globals()[full_path])
#     336                 elif full_path in (
#
# /usr/local/lib/python3.11/dist-packages/torch/_weights_only_unpickler.py in _get_user_allowed_globals()
#     142             rc[name] = f
#     143         else:
# --> 144             module, name = f.__module__, f.__name__
#     145             rc[f"{module}.{name}"] = f
#     146     return rc
#
# AttributeError: 'str' object has no attribute '__module__'

# %%
from torchvision import transforms

# ✅ Define the transformation (ToTensor)
to_tensor_transform = transforms.ToTensor()

def evaluate_model(model, test_loader, device):
    model.eval()
    total_correct, total_samples = 0, 0

    with torch.no_grad():
        for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
            # ✅ Convert images to tensors if they are not already
            images = [to_tensor_transform(img) if not isinstance(img, torch.Tensor) else img for img in images]

            # ✅ Move Data to the Same Device as Model
            images = torch.stack([img.to(device) for img in images])
            boxes = [b.to(device) for b in boxes]
            labels = [l.to(device) for l in labels]

            if len(labels) == 0 or len(boxes) == 0:
                print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
                continue

            # ✅ Normalize Bounding Boxes
            for i in range(len(boxes)):
                image_w, image_h = images.shape[3], images.shape[2]
                boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
                boxes[i] = torch.clamp(boxes[i], min=0, max=1)

            # ✅ Create Proper Targets List
            targets = [{"boxes": b, "labels": l} for b, l in zip(boxes, labels)]

            # ✅ Run Model Inference (Ensure Inputs Are on Same Device)
            outputs = model(images.to(device))

            # ✅ Compute Accuracy
            for output, target in zip(outputs, targets):
                pred_labels = output["labels"]
                gt_labels = target["labels"]

                # ✅ Match Predicted Labels with Ground Truth
                min_size = min(len(pred_labels), len(gt_labels))
                total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
                total_samples += min_size

            if batch_idx % 50 == 0:
                print(f"🔵 Batch {batch_idx}/{len(test_loader)} processed")

    accuracy = total_correct / total_samples if total_samples > 0 else 0.0
    print(f"✅ Evaluation Done: Accuracy {accuracy:.4f}")
    return accuracy

# ✅ Run Evaluation
accuracy = evaluate_model(model, test_loader, device)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-405316a162a3> in <cell line: 0>()
#      52
#      53 # ✅ Run Evaluation
# ---> 54 accuracy = evaluate_model(model, test_loader, device)
#
# <ipython-input-29-405316a162a3> in evaluate_model(model, test_loader, device)
#       9
#      10     with torch.no_grad():
# ---> 11         for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
#      12             # ✅ Convert images to tensors if they are not already
#      13             images = [to_tensor_transform(img) if not isinstance(img, torch.Tensor) else img for img in images]
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     706                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     707                 self._reset()  # type: ignore[call-arg]
# --> 708             data = self._next_data()
#     709             self._num_yielded += 1
#     710             if (
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1478                 del self._task_info[idx]
#    1479                 self._rcvd_idx += 1
# -> 1480                 return self._process_data(data)
#    1481
#    1482     def _try_put_index(self):
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1503         self._try_put_index()
#    1504         if isinstance(data, ExceptionWrapper):
# -> 1505             data.reraise()
#    1506         return data
#    1507
#
# /usr/local/lib/python3.11/dist-packages/torch/_utils.py in reraise(self)
#     731             # instantiate since we don't know how to
#     732             raise RuntimeError(msg) from None
# --> 733         raise exception
#     734
#     735
#
# TypeError: Caught TypeError in DataLoader worker process 0.
# Original Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/worker.py", line 349, in _worker_loop
#     data = fetcher.fetch(index)  # type: ignore[possibly-undefined]
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/torch/utils/data/_utils/fetch.py", line 55, in fetch
#     return self.collate_fn(data)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "<ipython-input-21-464b1fa6790b>", line 86, in collate_fn
#     images = torch.stack(images, dim=0)  # Stack images into a single tensor
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^
# TypeError: expected Tensor as element 0 in argument 0, but got Image

# %%
import torch
from torch.utils.data import DataLoader
from torch.nn.functional import interpolate
from collections import Counter

# ✅ Create Dataset & DataLoader (Optimized)
test_dataset = COCODataset("val2017", "annotations/instances_val2017.json", transform)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)

# ✅ COCO Labels
COCO_CLASSES = {
    1: "person", 2: "bicycle", 3: "car", 4: "motorcycle", 5: "airplane",
    6: "bus", 7: "train", 8: "truck", 9: "boat", 10: "traffic light",
    11: "fire hydrant", 13: "stop sign", 14: "parking meter", 15: "bench",
    16: "bird", 17: "cat", 18: "dog", 19: "horse", 20: "sheep",
    21: "cow", 22: "elephant", 23: "bear", 24: "zebra", 25: "giraffe",
    27: "backpack", 28: "umbrella", 31: "handbag", 32: "tie", 33: "suitcase",
    34: "frisbee", 35: "skis", 36: "snowboard", 37: "sports ball", 38: "kite",
    39: "baseball bat", 40: "baseball glove", 41: "skateboard", 42: "surfboard",
    43: "tennis racket", 44: "bottle", 46: "wine glass", 47: "cup", 48: "fork",
    49: "knife", 50: "spoon", 51: "bowl", 52: "banana", 53: "apple",
    54: "sandwich", 55: "orange", 56: "broccoli", 57: "carrot", 58: "hot dog",
    59: "pizza", 60: "donut", 61: "cake", 62: "chair", 63: "couch",
    64: "potted plant", 65: "bed", 67: "dining table", 70: "toilet",
    72: "tv", 73: "laptop", 74: "mouse", 75: "remote", 76: "keyboard",
    77: "cell phone", 78: "microwave", 79: "oven", 80: "toaster", 81: "sink",
    82: "refrigerator", 84: "book", 85: "clock", 86: "vase", 87: "scissors",
    88: "teddy bear", 89: "hair drier", 90: "toothbrush"
}

# ✅ Fixed Evaluation Function
# def evaluate_model(model, test_loader, device):
#     model.eval()
#     total_correct, total_samples = 0, 0
#     total_loss = 0.0

#     with torch.no_grad():
#         for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
#             images = torch.stack([img.to(device) for img in images])
#             boxes = [b.to(device) for b in boxes]
#             masks = [m.to(device) for m in masks]
#             labels = [l.to(device) for l in labels]

#             if len(labels) == 0 or len(boxes) == 0:
#                 print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
#                 continue

#             # ✅ Normalize Bounding Boxes
#             for i in range(len(boxes)):
#                 image_w, image_h = images.shape[3], images.shape[2]
#                 boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
#                 boxes[i] = torch.clamp(boxes[i], min=0, max=1)


#             # ✅ Create Proper Targets List
#             targets = []
#             for b, l in zip(boxes, labels):
#                 targets.append({"boxes": b, "labels": l})

#             # ✅ Run Model Inference


#             # class_logits = model(images)
#             # print(f"Model Output Type: {type(class_logits)}")
#             # print(f"Model Output Length: {len(class_logits) if isinstance(class_logits, (tuple, list)) else 'N/A'}")
#             # print("output keys: ", class_logits)
#             # print(f"First Output Type: {type(class_logits[0])}")
#             # print(f"Keys in First Output: {class_logits[0].keys() if isinstance(class_logits[0], dict) else 'Not a dict'}")

#             outputs = model(images)  # ✅ Get list of dictionaries
#             pred_labels = [output["labels"] for output in outputs]  # ✅ Extract 'labels'


#             # pred_labels = torch.argmax(class_logits, dim=1)
#             # gt_labels = torch.cat(labels, dim=0)

#             # # ✅ Ensure Matching Sizes for Accuracy Calculation
#             # min_size = min(pred_labels.shape[0], gt_labels.shape[0])
#             # total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
#             # total_samples += min_size

#             gt_labels = torch.cat(labels, dim=0) if len(labels) > 0 else torch.tensor([], device=device)
#             pred_labels = torch.cat(pred_labels, dim=0) if len(pred_labels) > 0 else torch.tensor([], device=device)

#             # Ensure both have the same shape before comparison
#             min_size = min(pred_labels.shape[0], gt_labels.shape[0])
#             total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
#             total_samples += min_size


#             # # ✅ Compute Losses
#             # loss_cls, loss_bbox, loss_mask = 0.0, 0.0, 0.0
#             # for output, target in zip(outputs, targets):
#             #     pred_boxes = output["boxes"]
#             #     pred_labels = output["labels"]
#             #     pred_scores = output["scores"]

#             #     # ✅ Match Predicted Labels with Ground Truth
#             #     gt_labels = target["labels"]
#             #     min_size = min(len(pred_labels), len(gt_labels))
#             #     total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
#             #     total_samples += min_size

#             # # ✅ Calculate Loss (For Debugging, Adjust as Needed)
#             # loss = loss_cls + loss_bbox + loss_mask
#             # total_loss += loss

#             if batch_idx % 50 == 0:
#                 print(f"🔵 Batch {batch_idx}/{len(test_loader)}: Loss {loss:.4f}")

#     accuracy = total_correct / total_samples if total_samples > 0 else 0.0
#     # avg_loss = total_loss / len(test_loader)
#     print(f"✅ Evaluation Done: Avg Loss {avg_loss:.4f}, Accuracy {accuracy:.4f}")
#     return avg_loss, accuracy




def evaluate_model(model, test_loader, device):
    model.eval()
    total_correct, total_samples = 0, 0

    with torch.no_grad():
        for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
            images = torch.stack([img.to(device) for img in images])
            labels = [l.to(device) for l in labels]

            if len(labels) == 0:
                print(f"⚠️ Skipping batch {batch_idx} due to empty labels")
                continue

            outputs = model(images)
            pred_labels = [output["labels"] for output in outputs]

            # Flatten & Convert Labels
            gt_labels = torch.cat(labels, dim=0) if len(labels) > 0 else torch.tensor([], device=device)
            pred_labels = torch.cat(pred_labels, dim=0) if len(pred_labels) > 0 else torch.tensor([], device=device)

            # Debugging: Print Sample Labels
            if batch_idx % 10 == 0:
                print(f"GT Labels: {gt_labels.tolist()}")
                print(f"Pred Labels: {pred_labels.tolist()}")

            # ✅ Ensure Labels Are in COCO Range
            if len(gt_labels) > 0 and len(pred_labels) > 0:
                assert gt_labels.min() >= 1 and gt_labels.max() <= 90, "GT labels out of range!"
                assert pred_labels.min() >= 1 and pred_labels.max() <= 90, "Pred labels out of range!"

            # ✅ Match Predictions to Ground Truth
            matches = torch.isin(pred_labels, gt_labels)
            total_correct += matches.sum().item()
            total_samples += len(gt_labels)

            if batch_idx % 10 == 0:
                print("Predicted Label Distribution:", Counter(pred_labels.tolist()).most_common(5))

    accuracy = total_correct / total_samples if total_samples > 0 else 0.0
    print(f"✅ Evaluation Done: Accuracy {accuracy:.4f}")
    return accuracy

# ✅ Run Evaluation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
avg_loss, accuracy = evaluate_model(model, test_loader, device)

# %%
#testing code before changes

import torch
from torch.utils.data import DataLoader
from torch.nn.functional import interpolate

# ✅ Create Dataset & DataLoader (Optimized)
test_dataset = COCODataset("val2017", "annotations/instances_val2017.json", transform)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)

# ✅ COCO Labels
COCO_CLASSES = {
    1: "person", 2: "bicycle", 3: "car", 4: "motorcycle", 5: "airplane",
    6: "bus", 7: "train", 8: "truck", 9: "boat", 10: "traffic light",
    11: "fire hydrant", 13: "stop sign", 14: "parking meter", 15: "bench",
    16: "bird", 17: "cat", 18: "dog", 19: "horse", 20: "sheep",
    21: "cow", 22: "elephant", 23: "bear", 24: "zebra", 25: "giraffe",
    27: "backpack", 28: "umbrella", 31: "handbag", 32: "tie", 33: "suitcase",
    34: "frisbee", 35: "skis", 36: "snowboard", 37: "sports ball", 38: "kite",
    39: "baseball bat", 40: "baseball glove", 41: "skateboard", 42: "surfboard",
    43: "tennis racket", 44: "bottle", 46: "wine glass", 47: "cup", 48: "fork",
    49: "knife", 50: "spoon", 51: "bowl", 52: "banana", 53: "apple",
    54: "sandwich", 55: "orange", 56: "broccoli", 57: "carrot", 58: "hot dog",
    59: "pizza", 60: "donut", 61: "cake", 62: "chair", 63: "couch",
    64: "potted plant", 65: "bed", 67: "dining table", 70: "toilet",
    72: "tv", 73: "laptop", 74: "mouse", 75: "remote", 76: "keyboard",
    77: "cell phone", 78: "microwave", 79: "oven", 80: "toaster", 81: "sink",
    82: "refrigerator", 84: "book", 85: "clock", 86: "vase", 87: "scissors",
    88: "teddy bear", 89: "hair drier", 90: "toothbrush"
}

# ✅ Fixed Evaluation Function
def evaluate_model(model, test_loader, device):
    model.eval()
    total_correct, total_samples = 0, 0
    total_loss = 0.0

    with torch.no_grad():
        for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
            images = torch.stack([img.to(device) for img in images])
            boxes = [b.to(device) for b in boxes]
            masks = [m.to(device) for m in masks]
            labels = [l.to(device) for l in labels]

            if len(labels) == 0 or len(boxes) == 0:
                print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
                continue

            # ✅ Normalize Bounding Boxes
            for i in range(len(boxes)):
                image_w, image_h = images.shape[3], images.shape[2]
                boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
                boxes[i] = torch.clamp(boxes[i], min=0, max=1)

            # ✅ Create Proper Targets List
            targets = []
            for b, l in zip(boxes, labels):
                targets.append({"boxes": b, "labels": l})

            # ✅ Run Model Inference
            outputs = model(images)

            # ✅ Compute Losses
            loss_cls, loss_bbox, loss_mask = 0.0, 0.0, 0.0
            for output, target in zip(outputs, targets):
                pred_boxes = output["boxes"]
                pred_labels = output["labels"]
                pred_scores = output["scores"]

                # ✅ Match Predicted Labels with Ground Truth
                gt_labels = target["labels"]
                min_size = min(len(pred_labels), len(gt_labels))
                total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
                total_samples += min_size

            # ✅ Calculate Loss (For Debugging, Adjust as Needed)
            loss = loss_cls + loss_bbox + loss_mask
            total_loss += loss

            if batch_idx % 50 == 0:
                print(f"🔵 Batch {batch_idx}/{len(test_loader)}: Loss {loss:.4f}")

    accuracy = total_correct / total_samples if total_samples > 0 else 0.0
    avg_loss = total_loss / len(test_loader)
    print(f"✅ Evaluation Done: Avg Loss {avg_loss:.4f}, Accuracy {accuracy:.4f}")
    return avg_loss, accuracy

# ✅ Run Evaluation
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
avg_loss, accuracy = evaluate_model(model, test_loader, device)

# %%
# import torch
# from torch.utils.data import DataLoader
# from torch.nn.functional import interpolate

# # ✅ Ensure Model is on the Correct Device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.to(device)

# # ✅ Create Dataset & DataLoader (Optimized)
# test_dataset = COCODataset("val2017", "annotations/instances_val2017.json", transform)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)

# # ✅ Evaluation Function
# def evaluate_model(model, test_loader, device):
#     model.eval()
#     total_correct, total_samples = 0, 0
#     total_loss = 0.0

#     with torch.no_grad():
#         for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
#             # ✅ Move Data to the Same Device as Model
#             images = torch.stack([img.to(device) for img in images])
#             boxes = [b.to(device) for b in boxes]
#             masks = [m.to(device) for m in masks]
#             labels = [l.to(device) for l in labels]

#             if len(labels) == 0 or len(boxes) == 0:
#                 print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
#                 continue

#             # ✅ Normalize Bounding Boxes
#             for i in range(len(boxes)):
#                 image_w, image_h = images.shape[3], images.shape[2]
#                 boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
#                 boxes[i] = torch.clamp(boxes[i], min=0, max=1)

#             # ✅ Create Proper Targets List
#             targets = []
#             for b, l in zip(boxes, labels):
#                 targets.append({"boxes": b, "labels": l})

#             # ✅ Run Model Inference (Ensure Inputs Are on Same Device)
#             outputs = model(images.to(device))

#             # ✅ Compute Accuracy
#             for output, target in zip(outputs, targets):
#                 pred_labels = output["labels"]
#                 gt_labels = target["labels"]

#                 # ✅ Match Predicted Labels with Ground Truth
#                 min_size = min(len(pred_labels), len(gt_labels))
#                 total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
#                 total_samples += min_size

#             if batch_idx % 50 == 0:
#                 print(f"🔵 Batch {batch_idx}/{len(test_loader)} processed")

#     accuracy = total_correct / total_samples if total_samples > 0 else 0.0
#     print(f"✅ Evaluation Done: Accuracy {accuracy:.4f}")
#     return accuracy

# # ✅ Run Evaluation
# accuracy = evaluate_model(model, test_loader, device)

# %%
# import torch
# import cv2
# import numpy as np
# import matplotlib.pyplot as plt
# from torchvision.transforms import functional as F
# from torch.utils.data import DataLoader
# from torch.nn.functional import interpolate

# # ✅ Load Model & Move to Correct Device
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
# model.to(device)

# # ✅ COCO Dataset Class Names (91 Classes)
# class_names = ["background"] + [f"Class_{i}" for i in range(1, 91)]  # Replace with actual COCO class names if available

# # ✅ Function to Detect Objects & Masks
# def detect_masked_regions(model, image, device, threshold=0.5):
#     model.eval()
#     image_tensor = F.to_tensor(image).unsqueeze(0).to(device)

#     with torch.no_grad():
#         outputs = model(image_tensor)

#     pred_scores = outputs[0]['scores'].cpu().numpy()
#     pred_labels = outputs[0]['labels'].cpu().numpy()
#     pred_masks = outputs[0]['masks'].cpu().numpy()
#     pred_boxes = outputs[0]['boxes'].cpu().numpy()

#     valid_indices = pred_scores > threshold  # Apply confidence threshold
#     return pred_boxes[valid_indices], pred_masks[valid_indices], pred_labels[valid_indices]

# # ✅ Function to Visualize Predictions
# def visualize_predictions(image, boxes, masks, labels, class_names):
#     image = np.array(image, dtype=np.uint8)
#     overlay = image.copy()

#     for box, mask, label in zip(boxes, masks, labels):
#         mask = mask[0] > 0.5  # Convert mask to binary
#         color = np.random.randint(0, 255, (3,), dtype=np.uint8)
#         overlay[mask] = 0.5 * overlay[mask] + 0.5 * color  # Apply mask overlay

#         x1, y1, x2, y2 = map(int, box)
#         cv2.rectangle(image, (x1, y1), (x2, y2), color.tolist(), 2)
#         text = class_names[label] if label < len(class_names) else "Unknown"
#         cv2.putText(image, text, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, color.tolist(), 2)

#     combined = cv2.addWeighted(image, 0.6, overlay, 0.4, 0)
#     plt.figure(figsize=(10, 10))
#     plt.imshow(cv2.cvtColor(combined, cv2.COLOR_BGR2RGB))
#     plt.axis("off")
#     plt.show()

# # ✅ Function to Evaluate Model Accuracy
# def evaluate_model(model, test_loader, device):
#     model.eval()
#     total_correct, total_samples = 0, 0

#     with torch.no_grad():
#         for batch_idx, (images, boxes, masks, labels) in enumerate(test_loader):
#             # ✅ Move Data to GPU/CPU
#             images = torch.stack([img.to(device) for img in images])
#             boxes = [b.to(device) for b in boxes]
#             masks = [m.to(device) for m in masks]
#             labels = [l.to(device) for l in labels]

#             if len(labels) == 0 or len(boxes) == 0:
#                 print(f"⚠️ Skipping batch {batch_idx} due to empty labels/boxes")
#                 continue

#             # ✅ Normalize Bounding Boxes
#             for i in range(len(boxes)):
#                 image_w, image_h = images.shape[3], images.shape[2]
#                 boxes[i] /= torch.tensor([image_w, image_h, image_w, image_h], device=device)
#                 boxes[i] = torch.clamp(boxes[i], min=0, max=1)

#             # ✅ Create Proper Targets List
#             targets = [{"boxes": b, "labels": l} for b, l in zip(boxes, labels)]

#             # ✅ Run Model Inference
#             outputs = model(images.to(device))

#             # ✅ Compute Accuracy
#             for output, target in zip(outputs, targets):
#                 pred_labels = output["labels"]
#                 gt_labels = target["labels"]

#                 min_size = min(len(pred_labels), len(gt_labels))
#                 total_correct += (pred_labels[:min_size] == gt_labels[:min_size]).sum().item()
#                 total_samples += min_size

#             if batch_idx % 50 == 0:
#                 print(f"🔵 Batch {batch_idx}/{len(test_loader)} processed")

#     accuracy = total_correct / total_samples if total_samples > 0 else 0.0
#     print(f"✅ Evaluation Done: Accuracy {accuracy:.4f}")
#     return accuracy

# # ✅ Create Dataset & DataLoader (Optimized)
# test_dataset = COCODataset("val2017", "annotations/instances_val2017.json", transform)
# test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True, collate_fn=collate_fn, num_workers=4)

# # ✅ Run Evaluation
# accuracy = evaluate_model(model, test_loader, device)

# # ✅ Example Usage
# image_path = "sample.jpg"
# image = cv2.imread(image_path)
# image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# # ✅ Detect Masked Regions
# boxes, masks, labels = detect_masked_regions(model, image, device)

# # ✅ Visualize Results
# visualize_predictions(image, boxes, masks, labels, class_names)

# %%
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
import cv2
from torchvision.models.detection import maskrcnn_resnet50_fpn
from PIL import Image

# ✅ Set Device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# ✅ Load the Model
#model = maskrcnn_resnet50_fpn(pretrained=False, num_classes=91).to(device)

# ✅ Load the trained weights
model.load_state_dict(torch.load("mask_rcnn_trained.pth", map_location=device), strict=False)

# ✅ Set model to evaluation mode
model.eval()
print("✅ Model loaded successfully for testing!")

# ✅ Enhanced Preprocessing Function
def preprocess_image(image_path):
    image = cv2.imread(image_path)
    original_size = image.shape[:2][::-1]  # (width, height)

    # ✅ Convert to Grayscale
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

    # ✅ Apply CLAHE (Adaptive Histogram Equalization)
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8,8))
    gray = clahe.apply(gray)

    # ✅ Apply Bilateral Filter (Preserves Edges)
    filtered = cv2.bilateralFilter(gray, 9, 75, 75)

    # ✅ Convert back to 3-channel image
    processed_image = cv2.cvtColor(filtered, cv2.COLOR_GRAY2RGB)

    # ✅ Convert to PIL for Transformations
    pil_image = Image.fromarray(processed_image)

    # ✅ Apply Torchvision Transformations
    transform = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.5], std=[0.5])  # Normalize grayscale values
    ])
    image_tensor = transform(pil_image).unsqueeze(0)  # Add batch dimension

    return image_tensor.to(device), image, original_size

# ✅ Function to Detect Masked Regions & Draw Bounding Boxes
def detect_masked_regions(image_np):
    # Convert to HSV for color-based segmentation
    hsv = cv2.cvtColor(image_np, cv2.COLOR_BGR2HSV)

    # ✅ Define a range for the masked color (e.g., blue tint in this case)
    lower_bound = np.array([90, 50, 50])   # Lower HSV range
    upper_bound = np.array([140, 255, 255])  # Upper HSV range

    # ✅ Create a Mask
    mask = cv2.inRange(hsv, lower_bound, upper_bound)

    # ✅ Find Contours of Masked Areas
    contours, _ = cv2.findContours(mask, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # ✅ Draw Bounding Boxes
    for cnt in contours:
        x, y, w, h = cv2.boundingRect(cnt)
        cv2.rectangle(image_np, (x, y), (x + w, y + h), (255, 0, 0), 3)  # Blue Box

    return image_np

# ✅ Updated Visualization Function (Now with Bounding Boxes on Masked Areas)
def visualize_predictions(original_image, original_size, outputs, threshold=0.8):
    image_np = np.array(original_image)  # Convert PIL image to NumPy
    image_np = cv2.cvtColor(image_np, cv2.COLOR_RGB2BGR)  # Convert to OpenCV format

    # ✅ Detect & Draw Bounding Boxes on Masked Regions
    image_np = detect_masked_regions(image_np)

    # ✅ Display the Image
    plt.figure(figsize=(10, 10))
    plt.imshow(cv2.cvtColor(image_np, cv2.COLOR_BGR2RGB))
    plt.axis("off")
    plt.title("Detected Masked Areas with Bounding Boxes")
    plt.show()

# ✅ Specify Image Path
image_path = "val2017/000000000785.jpg"  # Change this to your test image

# ✅ Load & Predict on the Selected Image
image_tensor, original_image, original_size = preprocess_image(image_path)

# ✅ Run Inference
with torch.no_grad():
    outputs = model(image_tensor)[0]  # Get first image output

# ✅ Visualize Results (Bounding Boxes Around Masked Regions)
visualize_predictions(original_image, original_size, outputs)
